# %% [markdown]
# PyLadies | Intermediate Python
# ==============================
#
# ### Paul Logston on 2014-05-16

# %% [markdown]
# ## What will we cover?
#
#  - Breif review of the basics (20 min)
#      - list comphrensions
#      - dictionary comprehensions
#  - Objects (20 min)
#      - multiple inheritance
#  - Exceptions (15 min)
#      - pdb
#      - raising your own
#      - handling them
#  - unittests (10 min)
#  - import requests, BeautifulSoup, & parse a web page (20 min)
#  - import matplotlib & graphing (20 min)
#  - Decorators (20 min)
#  - Generators (20 min)

# %% [markdown]
# ### What we need

# %%
from collections import Counter
import math
from pprint import pprint
import sys
import unittest

from bs4 import BeautifulSoup
import requests
import sqlalchemy

# %% [markdown]
# ## Some Basics
#
# ### List Comprehensions
# #### https://docs.python.org/2/tutorial/datastructures.html#list-comprehensions

# %%
book0 = {'title': 'What a great book!', 'pages': 42, 'author': 'Aurthor Authington'} 
book1 = {'title': 'The beauty of a day inside with Python.', 'pages': 330, 'author': 'Mike Lane'}
book2 = {'title': 'Did some one say MadMen?', 'pages': 971, 'author': 'The Hulk'}

shelf = [book0, book1, book2]  # Order of items in list preserved.

# %% [markdown]
# What if I wanted to add an ID to each book based on its order within shelf?

# %%
id = 0
for book in shelf:
    book['id'] = id
    id += 1
pprint(shelf)
# Out:
# [{'author': 'Aurthor Authington',
#   'id': 0,
#   'pages': 42,
#   'title': 'What a great book!'},
#  {'author': 'Mike Lane',
#   'id': 1,
#   'pages': 330,
#   'title': 'The beauty of a day inside with Python.'},
#  {'author': 'The Hulk',
#   'id': 2,
#   'pages': 971,
#   'title': 'Did some one say MadMen?'}]

# %% [markdown]
# But lets use some of the tools that make Python Python.

# %%
shelf = [dict(book.items() + {'id': n}.items()) for n, book in enumerate(shelf)]
pprint(shelf)
# Out:
# [{'author': 'Aurthor Authington',
#   'id': 0,
#   'pages': 42,
#   'title': 'What a great book!'},
#  {'author': 'Mike Lane',
#   'id': 1,
#   'pages': 330,
#   'title': 'The beauty of a day inside with Python.'},
#  {'author': 'The Hulk',
#   'id': 2,
#   'pages': 971,
#   'title': 'Did some one say MadMen?'}]

# %%
book1.items()  # .items() gives us back a list of 2-tuples. Side note: Why didn't we see our 'id' in book1's list of tuples?
# Out:
# [('id', 1),
#  ('author', 'Mike Lane'),
#  ('pages', 330),
#  ('title', 'The beauty of a day inside with Python.')]

# %% [markdown]
# ### Dictionary Comprehensions
# #### https://docs.python.org/2/tutorial/datastructures.html#dictionaries

# %%
experiment = {
    'sensor1': [91, 58, 41, 98, 66, 60, 70, 43, 96, 79],
    'sensor2': [43, 42, 83, 83, 69, 68, 43, 42, 53, 63],
    'sensor3': [82, 62, 93, 99, 53, 60, 79, 52, 52, 59],
    'sensor4': [52, 88, 72, 83, 65, 53, 41, 69, 73, 66],
    'sensor5': [83, 76, 76, 81, 45, 49, 64, 80, 43, 61],
    # ...
}

# %% [markdown]
# NB. I ran...
#
#     python -c "import random; print [random.randint(40, 100) for _ in range(10)]"
#
# at the command line 5 times to get this fake data.

# %% [markdown]
# I need to find the average temparture for each sensor.

# %%
avg = lambda seq: sum(seq) / len(seq)  # Lambda function.

{sensor: avg(temps) for sensor, temps in experiment.items()}
# Out:
# {'sensor1': 70, 'sensor2': 58, 'sensor3': 69, 'sensor4': 66, 'sensor5': 65}

# %% [markdown]
# What if we had some false readings in our data and we wanted to exculde those values that clearly wrong (ie. negative values)? Let's assume we are on a Kelvin scale.

# %%
experiment = {
    'sensor1': [91, 2, 6, 32, 24, 64, 19, 18, -5, 38],
    'sensor2': [18, -3, 83, 7, 63, 52, 11, -4, 42, 16],
    'sensor3': [1, 24, 0, -5, 74, 15, -1, 27, -5, 88],
    'sensor4': [26, 45, 35, -7, 63, 14, 15, 12, 19, 91],
    'sensor5': [78, 21, -9, -6, 52, 83, 79, 78, 13, 10],
    # ...
}
{sensor: avg([temp for temp in temps if temp > 0]) for sensor, temps in experiment.items()}
# Out:
# {'sensor1': 32, 'sensor2': 36, 'sensor3': 38, 'sensor4': 35, 'sensor5': 51}

# %%
# Remove negative values by hand.
experiment_no_negative_values = {
    'sensor1': [91, 2, 6, 32, 24, 64, 19, 18, 38],
    'sensor2': [18, 83, 7, 63, 52, 11, 42, 16],
    'sensor3': [1, 24, 0, 74, 15, 27, 88],
    'sensor4': [26, 45, 35, 63, 14, 15, 12, 19, 91],
    'sensor5': [78, 21, 52, 83, 79, 78, 13, 10],
    # ...
}
{sensor: avg(temps) for sensor, temps in experiment_no_negative_values.items()}
# Out:
# {'sensor1': 32, 'sensor2': 36, 'sensor3': 32, 'sensor4': 35, 'sensor5': 51}

# %% [markdown]
# ## Objects

# %% [markdown]
# Wouldn't it be great if we had a data sturcture that, like a list or dictionary, held data for but held data in form that was more specific to our use case? Wouldn't it be great if that data structure had functions attached it and those functions could manipulate the data in ways that made sense given what data we have and our use case?

# %%
class Book(object):  # What is object doing here? https://docs.python.org/release/2.2.3/whatsnew/sect-rellinks.html#SECTION00031
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages
book1 = Book('Sun on a Sunday: A day at the beach!', 'Glenda Roberts', 44)

# %%
book1

# %%
book1.title
# Out:
# 'Sun on a Sunday: A day at the beach!'

# %%
book1.title = 'Sun on a Sunday'
book1.subtitle = 'A day at the beach!'

# %%
book1.subtitle
# Out:
# 'A day at the beach!'

# %% [markdown]
# I need a function that returns the number of pages I will need to print when I produce a book.
# Let's assume that I have to print an extra 5 per book when producing a book.
#
# Let's also assume that the cost of producing a book is specified by this function:
#
#     cost of printing a book ($) = square root of the number of pages we need to print to produce the book.

# %%
class Book(object):
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages

    def printed_pages(self):
        return self.pages + 5
    
    def cost(self):
        return math.sqrt(self.printed_pages())

# %%
book1 = Book('Sun on a Sunday: A day at the beach!', 'Glenda Roberts', 44)
book1.printed_pages()
# Out:
# 49

# %%
book1.cost()
# Out:
# 7.0

# %% [markdown]
# ### Method Resolution Order / Multiple Inheritance
# #### https://docs.python.org/2/tutorial/classes.html#multiple-inheritance

# %%
class PrintableMixin(object):
    def cost(self):
        return math.sqrt(self.printed_pages())
    
class Book(PrintableMixin, object):
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages

    def printed_pages(self):
        return self.pages + 5
    
class Magazine(PrintableMixin, object):
    def __init__(self, title, volume, pages):
        self.title = title
        self.volume = volume
        self.pages = pages

    def printed_pages(self):
        return self.pages + 2

# %%
Book('Sun on a Sunday: A day at the beach!', 'Glenda Roberts', 44).cost()
# Out:
# 7.0

# %%
Magazine('Python and Pythons: Analyzing serpents with your favorite scripting language.', 11, 79).cost()
# Out:
# 9.0

# %%
class BooMag(Book, Magazine):
    def __init__(self, title, author, volume, pages):
        super(Book, self).__init__(title, author, pages)
        super(Magazine, self).__init__()

# %%
BooMag("Which One's it going to be?", 'Gina James', 12, 44).cost()
# Out:
# 7.0

# %%
class MagBoo(Magazine, Book):
    def __init__(self, title, author, volume, pages):
        super(Book, self).__init__()
        super(Magazine, self).__init__(title, volume, pages)

# %%
MagBoo("Which One's it going to be?", 'Gina James', 12, 79).cost()
# Out:
# 9.0

# %%
m = MagBoo('You,', 'Auth', 1, 84)

# %%
b = BooMag('You,', 'Auth', 1, 84)

# %%
b.author
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-7ac941eedab9> in <module>()
# ----> 1 b.author
#
# AttributeError: 'BooMag' object has no attribute 'author'

# %% [markdown]
# QUESTION TO ASK. Why can't we have multiple objects providing properties/attributes (another q, what is the proper term) to these objects?

# %% [markdown]
# ## Exceptions
# #### https://docs.python.org/2/tutorial/errors.html

# %%
d = {'name': 'Pat'}

# %%
d[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-17371c6688f6> in <module>()
# ----> 1 d[0]
#
# KeyError: 0

# %% [markdown]
# Or if we ran these two lines in the REPL...
#
#     Traceback (most recent call last):
#       File "<stdin>", line 1, in <module>
#     KeyError: 0

# %% [markdown]
# So what's a ``KeyError``?
# https://wiki.python.org/moin/KeyError

# %%
d.get(0, 'Woot')
# Out:
# 'Woot'

# %% [markdown]
#     ---------------------------------------------------------------------------
#     NameError                                 Traceback (most recent call last)
#     <ipython-input-57-bb4e4829bd83> in <module>()
#           1 book1 = Book('Sun on a Sunday: A day at the beach!', 'Glenda Roberts', 49)
#           2 book1.printed_pages()
#     ----> 3 book1.cost()
#
#     <ipython-input-56-5f6ed6724802> in cost(self)
#           9
#          10     def cost(self):
#     ---> 11         return math.sqrt(self.printed_pages())
#
#     NameError: global name 'math' is not defined

# %% [markdown]
# https://docs.python.org/2/library/exceptions.html#exceptions.NameError

# %% [markdown]
# This gives us a little more info on what is going on:
#
#     global name 'math' is not defined

# %% [markdown]
# ### pdb (The Python Debugger)
# #### https://docs.python.org/2/library/pdb.html#module-pdb

# %% [markdown]
# #### Lets debug!
#
#     n(ext)
#     s(tep)
#     c(ontinue)
#     q(uit)

# %% [markdown]
# Exercise #1

# %%
def broken_addition(x, y):
    return_value = x + y + 1
    return return_value
broken_addition(1, 1)
# Out:
# 3

# %% [markdown]
#     def broken_addition(x, y):
#         import pdb; pdb.set_trace()
#         return_value = x + y + 1
#         return return_value
#     broken_addition(1, 1)
#
# or
#
#     $ python -m pdb path/to/broken_addition.py

# %% [markdown]
# Exercise #2

# %% [markdown]
#     $ python -c "import this" > ~/zen

# %% [markdown]
#     with open('/Users/paul/zen') as fd:
#         lines = fd.read()
#         for line in lines:
#             print line

# %% [markdown]
# #### Lets raise our own exceptions.

# %%
def subtract(x, y):
    """
    This function should aways return a non-negative value.
    """
    if x < y:
        raise ValueError('Value received for x is less ' 
                         'than y. This is not allowed.')
    return x - y

# %%
s = subtract(4, 5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-33b35e5eb084> in <module>()
# ----> 1 s = subtract(4, 5)
#
# <ipython-input-45-058ac3c66f02> in subtract(x, y)
#       4     """
#       5     if x < y:
# ----> 6         raise ValueError('Value received for x is less '
#       7                          'than y. This is not allowed.')
#       8     return x - y
#
# ValueError: Value received for x is less than y. This is not allowed.

# %% [markdown]
# Exception Hierarchy: https://docs.python.org/2/library/exceptions.html#exception-hierarchy

# %% [markdown]
# #### Let's handle this.

# %%
def this_might_work():
    raise ValueError('Nope')
    raise StandardError('Sorry')
    raise BufferError('rebuffed')
    raise ArithmeticError('better check your numbers')
    raise FloatingPointError('')
    raise OverflowError('')
    raise ZeroDivisionError('')
    
    print ('hi!')

this_might_work()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-8defc3ce630c> in <module>()
#      10     print ('hi!')
#      11
# ---> 12 this_might_work()
#
# <ipython-input-71-8defc3ce630c> in this_might_work()
#       1 def this_might_work():
# ----> 2     raise ValueError('Nope')
#       3     raise StandardError('Sorry')
#       4     raise BufferError('rebuffed')
#       5     raise ArithmeticError()
#
# ValueError: Nope

# %%
try:
    this_might_work()
except:
    print ("Didn't work out this time")
# Out:
# Didn't work out this time

# %%
try:
    this_might_work()
except:
    print ("Didn't work out this time")
finally:
    print ("Let's Dance")
# Out:
# Didn't work out this time
# Let's Dance

# %% [markdown]
# ## unit tests!

# %%
def addition(x, y):
    return x + y + 1

class PyLadiesTC(unittest.TestCase):
    def test_best_practices(self):
        return_value = addition(1, 2)
        self.assertEqual(return_value, 3)

suite = unittest.TestLoader().loadTestsFromTestCase(PyLadiesTC)
unittest.TextTestRunner().run(suite)
# Out:
# F
# ======================================================================
# FAIL: test_best_practices (__main__.PyLadiesTC)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-67-6218f542afae>", line 7, in test_best_practices
#     self.assertEqual(return_value, 3)
# AssertionError: 4 != 3
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# FAILED (failures=1)
# <unittest.runner.TextTestResult run=1 errors=0 failures=1>

# %%
def check_facebook():
    sys.stdout.write("Checking FB\n")
    sys.stdout.flush()
    
def addition(x, y):
    return_value = x + y + 1
    return return_value

class PyLadiesTC(unittest.TestCase):
    def setUp(self):
        sys.stdout.write("Let's test\n")
        sys.stdout.flush()

    def tearDown(self):
        sys.stdout.write('All done with thit unit test\n')
        sys.stdout.flush()

    def test_my_addition_func_0(self):
        return_value = addition(1, 3)
        self.assertEqual(return_value, 4)
    
    def test_my_addition_func_1(self):
        return_value = addition(100, 100)
        self.assertEqual(return_value, 200)

    def love_testing(self):
        """Methods must start with test* to be run as a test"""
        check_facebook()

suite = unittest.TestLoader().loadTestsFromTestCase(PyLadiesTC)
unittest.TextTestRunner().run(suite)
# Out:
# Let's test
# F
# All done with thit unit test
# Let's test
# F
# All done with thit unit test
# ======================================================================
# FAIL: test_my_addition_func_0 (__main__.PyLadiesTC)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-857bb1e0bbaf>", line 20, in test_my_addition_func_0
#     self.assertEqual(return_value, 4)
# AssertionError: 5 != 4
#
# ======================================================================
# FAIL: test_my_addition_func_1 (__main__.PyLadiesTC)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-68-857bb1e0bbaf>", line 24, in test_my_addition_func_1
#     self.assertEqual(return_value, 200)
# AssertionError: 201 != 200
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.002s
#
# FAILED (failures=2)
# <unittest.runner.TextTestResult run=2 errors=0 failures=2>

# %% [markdown]
# ## requests & BeautifulSoup

# %%
r = requests.get('http://www.nytimes.com/')
r
# Out:
# <Response [200]>

# %%
r.content
# Out:
# '<!DOCTYPE html>\n<!--[if IE]><![endif]-->\n<html lang="en" class="NYT5Style">\n<head>\n<title>The New York Times - Breaking News, World News &amp; Multimedia</title>\n<meta http-equiv="X-UA-Compatible" content="IE=edge" /> \n<meta name="robots" content="noarchive,noodp,noydir">\n<meta name="description" content="Find breaking news, multimedia, reviews &amp; opinion on Washington, business, sports, movies, travel, books, jobs, education, real estate, cars &amp; more at nytimes.com.">\n<meta name="keywords" content="Muslim Americans,Informers,Police Department (NYC),Terrorism,United States International Relations,Kidnapping,Murders and Attempted Murders,Hadi, Abdu Rabbu Mansour,Yemen,Russia,Turchynov, Oleksandr V,Luhansk (Ukraine),Referendums,Putin, Vladimir V,Donetsk (Ukraine),Ponomaryov, Vyachislav,Ukraine,Acquired Immune Deficiency Syndrome,Schistosomiasis,Parasites,Women and Girls,Same-Sex Marriage, Civil Unions and Domestic Partnerships,News and News Media,Careers and Professions,Television,Roberts, Robin,Olatoye, Shola,New York City,Barrios-Paoli, Lilliam,Noerdlinger, Rachel,Lloyd, Emily,de Blasio, Bill,McCray, Chirlane,Santucci, Laura,Hiring and Promotion,Women and Girls,Ramirez, Ursulina,Glen, Alicia K,Farina, Carmen,New York City,de Blasio, Bill,Real Estate and Housing (Residential),Renting and Leasing (Real Estate),Art,Movies,Culture (Arts),Computers and the Internet,Mill Valley (Calif),Education (K-12),Code.org,New York Yankees,Sabathia, C C,Baseball,Defense and Military Forces,Iraq,Deaths (Fatalities),Terrorism,South Korea,Lee Kun-hee,Surgery and Surgeons,Heart,Medicine and Health,Samsung Group,Elections,Ghani, Ashraf,Afghanistan,Independent Election Commission (Afghanistan),Abdullah, Abdullah,Rassoul, Zalmay,Greenhouse Gas Emissions,Nordhaus, William D,Global Warming,Nordhaus, Robert,Children and Childhood,Nicaragua,Child Care,Families and Family Life,Socrates (1954-2011),World Cup (Soccer),Soccer,St John (Virgin Islands),Travel and Vacations,Camps and Camping,Parenting,Boats and Boating">\n<meta name="CG" content="Homepage">\n<meta name="SCG" content="">\n<meta name="PT" content="Homepage">\n<meta name="PST" content="">\n<meta name="HOMEPAGE_TEMPLATE_VERSION" content="300">\n<meta name="application-name" content="The New York Times" />\n<meta name="msapplication-starturl" content="http://www.nytimes.com/" />\n<meta name="msapplication-task" content="name=Search;action-uri=http://query.nytimes.com/search/sitesearch?src=iepin;icon-uri=http://css.nyt.com/images/icons/search.ico" />\n<meta name="msapplication-task" content="name=Most Popular;action-uri=http://www.nytimes.com/gst/mostpopular.html?src=iepin;icon-uri=http://css.nyt.com/images/icons/mostpopular.ico" />\n<meta name="msapplication-task" content="name=Video;action-uri=http://video.nytimes.com/?src=iepin;icon-uri=http://css.nyt.com/images/icons/video.ico" />\n<meta name="msapplication-task" content="name=Homepage;action-uri=http://www.nytimes.com?src=iepin&amp;adxnnl=1;icon-uri=http://css.nyt.com/images/icons/homepage.ico" />\n<link rel="shortcut icon" href="http://css.nyt.com/images/icons/nyt.ico" />\n<link rel="alternate" type="application/rss+xml" title="RSS" href="http://www.nytimes.com/services/xml/rss/nyt/HomePage.xml">\n<link rel="alternate" media="handheld" href="http://mobile.nytimes.com">    \n<link rel="stylesheet" type="text/css" href="http://css.nyt.com/css/0.1/screen/build/homepage/styles.css">\n<link rel="stylesheet" type="text/css" media="print" href="http://css.nyt.com/css/0.1/print/styles.css">\n<!--[if IE]>\n    <link rel="stylesheet" type="text/css" href="http://css.nyt.com/css/0.1/screen/build/homepage/ie.css?v=012611">\n<![endif]-->\n<!--[if IE 6]>\n    <link rel="stylesheet" type="text/css" href="http://css.nyt.com/css/0.1/screen/build/homepage/ie6.css">\n<![endif]-->\n<!--[if lt IE 9]>\n\t<script src="http://js.nyt.com/js/html5shiv.js"></script>\n<![endif]-->\n<script type="text/javascript" src="http://js.nyt.com/js2/build/sitewide/sit ...

# %%
soup = BeautifulSoup(r.content)
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IE]><![endif]-->
# <html class="NYT5Style" lang="en">
# <head>
# <title>The New York Times - Breaking News, World News &amp; Multimedia</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="noarchive,noodp,noydir" name="robots">
# <meta content="Find breaking news, multimedia, reviews &amp; opinion on Washington, business, sports, movies, travel, books, jobs, education, real estate, cars &amp; more at nytimes.com." name="description">
# <meta content="Muslim Americans,Informers,Police Department (NYC),Terrorism,United States International Relations,Kidnapping,Murders and Attempted Murders,Hadi, Abdu Rabbu Mansour,Yemen,Russia,Turchynov, Oleksandr V,Luhansk (Ukraine),Referendums,Putin, Vladimir V,Donetsk (Ukraine),Ponomaryov, Vyachislav,Ukraine,Acquired Immune Deficiency Syndrome,Schistosomiasis,Parasites,Women and Girls,Same-Sex Marriage, Civil Unions and Domestic Partnerships,News and News Media,Careers and Professions,Television,Roberts, Robin,Olatoye, Shola,New York City,Barrios-Paoli, Lilliam,Noerdlinger, Rachel,Lloyd, Emily,de Blasio, Bill,McCray, Chirlane,Santucci, Laura,Hiring and Promotion,Women and Girls,Ramirez, Ursulina,Glen, Alicia K,Farina, Carmen,New York City,de Blasio, Bill,Real Estate and Housing (Residential),Renting and Leasing (Real Estate),Art,Movies,Culture (Arts),Computers and the Internet,Mill Valley (Calif),Education (K-12),Code.org,New York Yankees,Sabathia, C C,Baseball,Defense and Military Forces,Iraq,Deaths (Fatalities),Terrorism,South Korea,Lee Kun-hee,Surgery and Surgeons,Heart,Medicine and Health,Samsung Group,Elections,Ghani, Ashraf,Afghanistan,Independent Election Commission (Afghanistan),Abdullah, Abdullah,Rassoul, Zalmay,Greenhouse Gas Emissions,Nordhaus, William D,Global Warming,Nordhaus, Robert,Children and Childhood,Nicaragua,Child Care,Families and Family Life,Socrates (1954-2011),World Cup (Soccer),Soccer,St John (Virgin Islands),Travel and Vacations,Camps and Camping,Parenting,Boats and Boating" name="keywords">
# <meta content="Homepage" name="CG">
# <meta content="" name="SCG">
# <meta content="Homepage" name="PT">
# <meta content="" name="PST">
# <meta content="300" name="HOMEPAGE_TEMPLATE_VERSION">
# <meta content="The New York Times" name="application-name"/>
# <meta content="http://www.nytimes.com/" name="msapplication-starturl"/>
# <meta content="name=Search;action-uri=http://query.nytimes.com/search/sitesearch?src=iepin;icon-uri=http://css.nyt.com/images/icons/search.ico" name="msapplication-task"/>
# <meta content="name=Most Popular;action-uri=http://www.nytimes.com/gst/mostpopular.html?src=iepin;icon-uri=http://css.nyt.com/images/icons/mostpopular.ico" name="msapplication-task"/>
# <meta content="name=Video;action-uri=http://video.nytimes.com/?src=iepin;icon-uri=http://css.nyt.com/images/icons/video.ico" name="msapplication-task"/>
# <meta content="name=Homepage;action-uri=http://www.nytimes.com?src=iepin&amp;adxnnl=1;icon-uri=http://css.nyt.com/images/icons/homepage.ico" name="msapplication-task"/>
# <link href="http://css.nyt.com/images/icons/nyt.ico" rel="shortcut icon"/>
# <link href="http://www.nytimes.com/services/xml/rss/nyt/HomePage.xml" rel="alternate" title="RSS" type="application/rss+xml">
# <link href="http://mobile.nytimes.com" media="handheld" rel="alternate">
# <link href="http://css.nyt.com/css/0.1/screen/build/homepage/styles.css" rel="stylesheet" type="text/css">
# <link href="http://css.nyt.com/css/0.1/print/styles.css" media="print" rel="stylesheet" type="text/css">
# <!--[if IE]>
#     <link rel="stylesheet" type="text/css" href="http://css.nyt.com/css/0.1/screen/build/homepage/ie.css?v=012611">
# <![endif]-->
# <!--[if IE 6]>
#     <link rel="stylesheet" type="text/css" href="http://css.nyt.com/css/0.1/screen/build/homepage/ie6.css">
# <![endif]-->
# <!--[if lt IE 9]>
# 	<script src="http://js.nyt.com/js/html5shiv.js"></script>
# <![endif]-->
# <script src="http://js.nyt.com/js2/build/sitewide/sitewide.js" type="text/javascript"></script>
# <script src="http://js.nyt.com/js2/build/homepage/top.js" type="text/javascript"></script>
# <script src="//typeface.nytimes.com/miq8eej.js"></script>
# <script>try{Typekit.load();}catch(e){}</script>
# <!-- ADXINFO classification="blank-but-count-imps" campaign="KRUX_DIGITAL_CONTROL_SCRIPT_LIVE_HP" priority="9100" isInlineSafe="N" width="1" height="1" --><!-- BEGIN Krux Controltag -->
# <script class="kxct" data-id="HrUwtkcl" data-version="async:1.7" type="text/javascript">
#   window.Krux||((Krux=function(){Krux.q.push(arguments)}).q=[]);
#   (function(){
#     var k=document.createElement('script');k.type='text/javascript';k.async=true;var m,src=(m=location.href.match(/\bkxsrc=([^&]+)\b/))&&decodeURIComponent(m[1]);
#     k.src=src||(location.protocol==='https:'?'https:':'http:')+'//cdn.krxd.net/controltag?confid=HrUwtkcl';
#     var s=document.getElementsByTagName('script')[0];s.parentNode.insertBefore(k,s);
#   })();
# </script>
# <!-- END Krux Controltag -->
# </link></link></link></link></meta></meta></meta></meta></meta></meta></meta></meta></head>
# <body id="home">
# <a name="top"></a>
# <div id="shell">
# <ul id="memberTools">
# <!-- ADXINFO classification="Text_Link" campaign="nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL" priority="8000" isInlineSafe="Y" width="0" height="0" --><!-- A/B test delivery snippet-->
# <span class="adxInfo" style="display:none;">campaign: nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL -- 245408, creative: nyt2014_bar1_simplify_ctrl_full_ad -- 371526, page: homepage.nytimes.com/index.html, targetedPage: homepage.nytimes.com/index.html, position: Bar1</span>
# <span class="abtest-config" data-campaigns='{
#     "Variation1":{"1":"466Q8","2":"466QF", "3" : "466QJ", "4" : "466QL", "5" : "466QR"},
#     "Variation2":{"1" :"46FWF", "2" : "46FWJ", "3" : "46FWL", "4" : "46FWR", "5" : "46FWW"}
#     }' data-dev="false" data-experiment-id="5HRZM7ODRt-RaNLs8RQDmQ" data-ga-mode="live" data-image-path="http://graphics8.nytimes.com/adx/images/ADS/37/15/ad.371526" data-path="//graphics8.nytimes.com/ab" data-test="other/bar1simplify_april_2014" style="display:none;"></span>
# <script src="//graphics8.nytimes.com/ab/bootstrap.js"></script>
# <!--end A/B test delivery snippet-->
# <style type="text/css">
#     .bar1simplify__markup {
#         display: none!important;
#     }
# </style>
# <li class="bar1simplify__markup user-subscriptions-menu user-subscriptions-group bar1_hover" id="bar1-3panel">
# <a class="" data-content-collection="B1NYTNow_Apr0" data-content-placement="1" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=Bar1&amp;sn2=5b35bc29/49f095e7&amp;sn1=aa2aa18e/6816dae&amp;camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&amp;ad=nyt2014_bar1_simplify_ctrl_full_ad&amp;goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp87JHJ%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D3Q64Y" id="nyt-button-sub" target="_blank">Subscribe Now</a>
# <div id="hovercard">
# <div id="top-panels">
# <div class="split split-hd">
# <div class="split-hd-content">
# <a data-content-collection="B1NYTNow_Apr0" data-content-placement="" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=Bar1&amp;sn2=5b35bc29/49f095e7&amp;sn1=c8cf6684/49c6fc07&amp;camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&amp;ad=nyt2014_bar1_simplify_ctrl_full_ad&amp;goto=https%3A%2F%2Fwww%2Enytimesathome%2Ecom%2Fhd%2F205%3FMediaCode%3DWB7AA%26CMP%3D3Q869" target="_blank"><img alt="The New York Times" src="http://graphics8.nytimes.com/adx/images/ADS/37/15/ad.371526/bar1-3panel-nyt.png"/></a>
# <!--[if IE 8]>    <h3 class="hover-title lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <h3 class="hover-title"> <!--<![endif]-->
# <a data-content-collection="B1NYTNow_Apr0" data-content-placement="" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=Bar1&amp;sn2=5b35bc29/49f095e7&amp;sn1=c8cf6684/49c6fc07&amp;camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&amp;ad=nyt2014_bar1_simplify_ctrl_full_ad&amp;goto=https%3A%2F%2Fwww%2Enytimesathome%2Ecom%2Fhd%2F205%3FMediaCode%3DWB7AA%26CMP%3D3Q869" target="_blank">Try Home Delivery for 50% Off 12 Weeks Plus Free All Digital Access</a>
# </h3>
# <p class="hover-subhead">
# <a data-content-collection="B1NYTNow_Apr0" data-content-placement="" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=Bar1&amp;sn2=5b35bc29/49f095e7&amp;sn1=c8cf6684/49c6fc07&amp;camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&amp;ad=nyt2014_bar1_simplify_ctrl_full_ad&amp;goto=https%3A%2F%2Fwww%2Enytimesathome%2Ecom%2Fhd%2F205%3FMediaCode%3DWB7AA%26CMP%3D3Q869" target="_blank">All print options include free, unlimited access to NYTimes.com, NYTimes apps and NYT Now.</a>
# </p>
# <a class="hdclick nyt-button-actions bar1button" data-content-collection="B1NYTNow_Apr0" data-content-placement="" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=Bar1&amp;sn2=5b35bc29/49f095e7&amp;sn1=c8cf6684/49c6fc07&amp;camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&amp;ad=nyt2014_bar1_simplify_ctrl_full_ad&amp;goto=https%3A%2F%2Fwww%2Enytimesathome%2Ecom%2Fhd%2F205%3FMediaCode%3DWB7AA%26CMP%3D3Q869" target="_blank">Get Home Delivery</a>
# </div>
# </div>
# <div class="split split-digi">
# <div class="split-digi-content">
# <a data-content-collection="B1NYTNow_Apr0" data-content-placement="" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=Bar1&amp;sn2=5b35bc29/49f095e7&amp;sn1=aa2aa18e/6816dae&amp;camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&amp;ad=nyt2014_bar1_simplify_ctrl_full_ad&amp;goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp5558%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D3Q86F" target="_blank"><img alt="nytimes.com" src="http://graphics8.nytimes.com/adx/images/ADS/37/15/ad.371526/bar1-3panel-nytcom.png"/></a>
# <!--[if IE 8]>    <h3 class="hover-title lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <h3 class="hover-title"> <!--<![endif]-->
# <a data-content-collection="B1NYTNow_Apr0" data-content-placement="" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=Bar1&amp;sn2=5b35bc29/49f095e7&amp;sn1=aa2aa18e/6816dae&amp;camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&amp;ad=nyt2014_bar1_simplify_ctrl_full_ad&amp;goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp5558%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D3Q86F" target="_blank">Try a Digital Subscription Today for Just 99¢ for Your First 4 Weeks</a>
# </h3>
# <p class="hover-subhead">
# <a data-content-collection="B1NYTNow_Apr0" data-content-placement="" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=Bar1&amp;sn2=5b35bc29/49f095e7&amp;sn1=aa2aa18e/6816dae&amp;camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&amp;ad=nyt2014_bar1_simplify_ctrl_full_ad&amp;goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp5558%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D3Q86F" target="_blank">Get unlimited access to NYTimes.com, NYTimes apps,<br>plus free NYT Now.</br></a>
# </p>
# <a class="digiclick nyt-button-actions bar1button" data-content-collection="B1NYTNow_Apr0" data-content-placement="" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=Bar1&amp;sn2=5b35bc29/49f095e7&amp;sn1=aa2aa18e/6816dae&amp;camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&amp;ad=nyt2014_bar1_simplify_ctrl_full_ad&amp;goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp5558%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D3Q86F" target="_blank">Get Digital</a>
# </div>
# </div>
# <div class="split split-nytnow">
# <div class="split-nytnow-content">
# <a data-content-collection="B1NYTNow_Apr0" data-content-placement="" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=Bar1&amp;sn2=5b35bc29/49f095e7&amp;sn1=aa2aa18e/6816dae&amp;camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&amp;ad=nyt2014_bar1_simplify_ctrl_full_ad&amp;goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp83KF8%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D44YQL" target="_blank"><img alt="NYT Now" src="http://graphics8.nytimes.com/adx/images/ADS/37/15/ad.371526/bar1-3panel-nytnow-trans.png"/></a>
# <!--[if IE 8]>    <h3 class="hover-title lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <h3 class="hover-title"> <!--<![endif]-->
# <a data-content-collection="B1NYTNow_Apr0" data-content-placement="" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=Bar1&amp;sn2=5b35bc29/49f095e7&amp;sn1=aa2aa18e/6816dae&amp;camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&amp;ad=nyt2014_bar1_simplify_ctrl_full_ad&amp;goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp83KF8%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D44YQL" target="_blank">Try NYT Now and Get Your First 4 Weeks Free</a>
# </h3>
# <p class="hover-subhead3">
# <a data-content-collection="B1NYTNow_Apr0" data-content-placement="" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=Bar1&amp;sn2=5b35bc29/49f095e7&amp;sn1=aa2aa18e/6816dae&amp;camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&amp;ad=nyt2014_bar1_simplify_ctrl_full_ad&amp;goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp83KF8%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D44YQL" target="_blank">A selection of top stories,<br>handpicked by editors. Available on NYTimes.com and a new iPhone® app.</br></a>
# </p>
# <a class="nytnowclick nyt-button-actions bar1button" data-content-collection="B1NYTNow_Apr0" data-content-placement="" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=Bar1&amp;sn2=5b35bc29/49f095e7&amp;sn1=aa2aa18e/6816dae&amp;camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&amp;ad=nyt2014_bar1_simplify_ctrl_full_ad&amp;goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp83KF8%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D44YQL" target="_blank">Get NYT Now</a>
# </div>
# </div>
# </div>
# <div class="split split-all">
# <a class="seeallclick split-all-button bar1button" data-content-collection="B1NYTNow_Apr0" data-content-placement="2" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=Bar1&amp;sn2=5b35bc29/49f095e7&amp;sn1=aa2aa18e/6816dae&amp;camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&amp;ad=nyt2014_bar1_simplify_ctrl_full_ad&amp;goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp87JHJ%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D466Q6" target="_blank">See All Subscriptions</a>
# </div>
# </div>
# </li><a class="bar1simplify__markup subscribe-link sub_small_hide" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=Bar1&amp;sn2=5b35bc29/49f095e7&amp;sn1=aa2aa18e/6816dae&amp;camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&amp;ad=nyt2014_bar1_simplify_ctrl_full_ad&amp;goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp87JHJ%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D3Q64Y" id="subscribe_small">Subscribe</a>
# <script id="bar1simplify_april_2014" type="text/html">
# <style class="bar1simplify__control__style" type="text/css">
#     .NYT5Style .masthead-tools #bar1-3panel  {
#         display: inline;
#         vertical-align: top;
#     }
#     #bar1-3panel {
#         border:none;
#         position: relative;
#     }
#     .bar1_hover {
#         opacity: 0;
#     }
#     .sub_small_hide{
#         display: none;
#     }
#     #bar1-3panel > a {
#         -moz-box-sizing: border-box;
#         background-color: #6288A5;
#         border: 1px solid #4D7B9F;
#         border-radius: 3px;
#         color: #FFFFFF !important;
#         display: inline-block;
#         font-size: 1em;
#         font-weight: bold;
#         font-family: nyt-franklin,nyt-franklin-1,'Helvetica Neue',Arial,sans-serif;
#         padding: 7px 10px 6px;
#         text-transform: uppercase;
#         text-decoration: none;
#     }
#     #bar1-3panel > a:hover {
#         background-color: #326891;
#         border: 1px solid #265E8B;
#         text-decoration: none;
#     }
#     #hovercard {
#         width: 513px;
#         height: 221px;
#         display:none;
#         margin-left: -360px;
#         z-index: 99999999;
#         background-color:#fff;
#         border:1px solid #ccc;
#         position:absolute;
#         left: 50%;
#         top: 28px;
#         text-align:left;
#         -moz-box-shadow: 0 0 5px #888;
#         -webkit-box-shadow: 0 0 5px#888;
#         box-shadow: 0 0 5px #888;
#         white-space: normal;
#     }
#     @media screen and (-webkit-min-device-pixel-ratio:0) {
#         /* CSS Statements that only apply on webkit-based browsers (Chrome, Safari, etc.) */
#         #hovercard {
#             top: 33px;
#         }
#     }
#     #top-panels {
#         width: 513px;
#         height: 190px;
#         background-color:#fff;
#         border:1px solid #ccc;
#         position:absolute;
#     }
#
#     #hovercard:before {
#         content:url(http://graphics8.nytimes.com/marketing/bar1jsimages/arrowup.png);
#         position:absolute;
#         left: 289px;
#         top: -14px;
#         width: 140px;
#         height:18px;
#         display:block;
#         text-align: center;
#         z-index: 1;
#     }
#     #hovercard h3.hover-title {
#         font-size: 13px;
#         line-height: 15px;
#         font-weight: bold;
#         font-style: normal;
#         font-family: 'nyt-franklin','Helvetica Neue',Arial,sans-serif;
#         color:#000;
#         width: 165px;
#         height: 35px;
#         position: absolute;
#         top: 45px;
#     }
#     #hovercard h3.lt-ie9 {
#         font-size: 12px;
#     }
#
#     .split-hd {
#         width: 170px;
#         margin:0;
#         padding: 0;
#         min-height: 196px;
#         border-right: 1px solid #e9e9e9;
#         float: left;
#         position: relative;
#     }
#
#     .split-digi {
#         width: 170px;
#         border-right:1px solid #e9e9e9;
#         margin: 0;
#         padding: 0;
#         min-height: 196px;
#         float:left;
#         position: relative;
#     }
#     .split-nytnow {
#         width: 170px;
#         margin: 0;
#         padding: 0;
#         min-height: 196px;
#         float: left;
#         position: relative;
#     }
#     .split-hd-content,
#     .split-digi-content,
#     .split-nytnow-content {
#         padding: 0 0px 0px 8px;
#     }
#     .split-hd:hover,
#     .split-digi:hover,
#     .split-nytnow:hover {
#         background-color:#f8f8f8;
#     }
#     .hover-subhead {
#         font-family: 'nyt-franklin', 'Helvetica Neue', Arial, sans-serif;
#         font-weight: 400;
#         font-size: 10px;
#         line-height: 13px;
#         color: #333;
#         margin: 5px 0 0;
#         width: 160px;
#         position: absolute;
#         top: 88px;
#     }
#     .hover-subhead3 {
#         font-family: 'nyt-franklin', 'Helvetica Neue', Arial, sans-serif;
#         font-weight: 400;
#         font-size: 10px;
#         line-height: 13px;
#         color: #333;
#         margin: 5px 0 0;
#         width: 155px;
#         position: absolute;
#         top: 74px;
#     }
#
#     #hovercard h3 a,
#     #hovercard p a {
#         color:#000 !important;
#         text-decoration: none;
#         display: block;
#     }
#     #hovercard img {
#         margin: 20px 0 -5px;
#     }
#
#     div.split-all {
#     }
#
#     a.split-all-button {
#         background: #f2f2f2;
#         width:513px;
#         height: 28px;
#         margin-top: 7px;
#         height: 28px;
#         position: absolute;
#         bottom: 0px;
#         font:12px "nyt-franklin", "Helvetica Neue", Arial, sans-serif;
#         font-weight: 700;
#         line-height: 27px;
#         color:#000 !important;
#         margin:0;
#         border: 1px solid #CCC;
#         text-align: center;
#         vertical-align: middle;
#     }
#
#
#     #hovercard a.split-all-button:hover{
#         background:#ffffff;
#         color:#004276 !important;
#         text-decoration: underline !important;
#     }
#
#     a.nyt-button-actions {
#         background: #F7F7F5;
#         color: #004276;
#         width: 134px;
#         -webkit-border-radius:3px;
#         -moz-border-radius:3px;
#         border-radius:3px;
#         border:1px solid #ccc !important;
#         text-transform: uppercase;
#         font:11px "nyt-franklin", "Helvetica Neue", Arial, sans-serif;
#         text-align: center;
#         padding:6px 0;
#         cursor: pointer;
#         display: block;
#         position: absolute;
#         left: 16px;
#         bottom: 22px;
#         text-decoration: none !important;
#     }
#
#     #hovercard a.nyt-button-actions:hover {
#         background:#3C6791;
#         color:#fff !important;
#         text-decoration: none !important;
#     }
#
#     #hovercard a.nyt-button-actions.highlightButton:link,
#     #hovercard a.nyt-button-actions.highlightButton:visited {
#         color:#fff !important;
#         background:#3C6791;
#         text-decoration: none !important;
#     }
#
#     /* WEBKIT ONLY RULES */
#     @media screen and (-webkit-min-device-pixel-ratio:0) {
#         #masthead #hovercard {
#             margin-left: -386px !important;
#         }
#     }
#     /* EXCLUDING NYT4 INTERACTIVES */
#     #interactiveABC #bar1-3panel {
#         display: none;
#     }
#     </style>
#
# <style class="bar1simplify__var1__style" type="text/css">
#         .NYT5Style .masthead-tools #bar1-3panel  {
#             display: inline;
#             vertical-align: top;
#         }
#         #bar1-3panel {
#             border:none;
#             position: relative;
#         }
#         .bar1_hover {
#             opacity: 0;
#         }
#         .sub_small_hide{
#             display: none;
#         }
#         #bar1-3panel > a {
#             -moz-box-sizing: border-box;
#             background-color: #6288A5;
#             border: 1px solid #4D7B9F;
#             border-radius: 3px;
#             color: #FFFFFF !important;
#             display: inline-block;
#             font-size: 1em;
#             font-weight: bold;
#             font-family: nyt-franklin,nyt-franklin-1,'Helvetica Neue',Arial,sans-serif;
#             padding: 7px 10px 6px;
#             text-transform: uppercase;
#             text-decoration: none;
#         }
#         #bar1-3panel > a:hover {
#             background-color: #326891;
#             border: 1px solid #265E8B;
#             text-decoration: none;
#         }
#         #hovercard {
#             width: 200px;
#             height: 220px;
#             display:none;
#             margin-left: -42px;
#             z-index: 99999999;
#             background-color:#fff;
#             border:1px solid #ccc;
#             border-radius: 3px;
#             position:absolute;
#             left: 50%;
#             top: 28px;
#             text-align:left;
#             -moz-box-shadow: 0 0 5px #888;
#             -webkit-box-shadow: 0 0 5px#888;
#             box-shadow: 0 0 5px #888;
#             white-space: normal;
#             display: none;
#         }
#         @media screen and (-webkit-min-device-pixel-ratio:0) {
#             /* CSS Statements that only apply on webkit-based browsers (Chrome, Safari, etc.) */
#             #hovercard {
#                 top: 33px;
#             }
#         }
#         #top-panels {
#             width: 191px;
#             height: 189px;
#             background-color:#fff;
#             border-radius: 3px;
#             position:absolute;
#             padding: 5px;
#         }
#
#         #hovercard:before {
#             content:url(http://graphics8.nytimes.com/marketing/bar1jsimages/arrowup.png);
#             position:absolute;
#             left: -10px;
#             top: -14px;
#             width: 140px;
#             height: 18px;
#             display:block;
#             text-align: center;
#             z-index: 1;
#         }
#
#         .split-content {
#             padding-top: 6px;
#             padding-left: 12px;
#         }
#         .split-offer {
#             min-width: 170px;
#             padding: 0;
#             min-height: 52px;
#             /*border-bottom: 1px solid #e9e9e9;*/
#             position: relative;
#         }
#         .split-offer:hover {
#             background-color:#f7f8f8;
#         }
#
#         #hovercard hr {
#             margin: 5px;
#             width: 178px;
#             color: #e3e3e3;
#         }
#
#         h3.hover-title {
#             font-size: 13px;
#             line-height: 15px;
#             font-weight: 700;
#             font-style: normal;
#             font-family: 'nyt-franklin','Helvetica Neue',Arial,sans-serif;
#             color:#000;
#             height: 15px;
#         }
#
#         .hover-title a {
#             outline: none;
#         }
#
#         .hover-subhead {
#             font-family: 'nyt-franklin', 'Helvetica Neue', Arial, sans-serif;
#             font-weight: 400;
#             font-size: 11px;
#             line-height: 13px;
#             color: #333;
#             margin: 1px 0 0;
#         }
#
#         .hover-subhead a {
#             outline: none;
#         }
#
#         #hovercard h3 a,
#         #hovercard p a {
#             color:#000 !important;
#             text-decoration: none;
#             display: block;
#         }
#
#         a.nyt-button-actions {
#             background: #F7F7F5;
#             color: #303030;
#             width: 134px;
#             -webkit-border-radius:3px;
#             -moz-border-radius:3px;
#             border-radius:3px;
#             border:1px solid #ccc !important;
#             text-transform: uppercase;
#             font:11px "nyt-franklin", "Helvetica Neue", Arial, sans-serif;
#             text-align: center;
#             padding:8px 0;
#             cursor: pointer;
#             display: block;
#             position: relative;
#             left: 270px;
#             bottom: 6px;
#             text-decoration: none !important;
#         }
#
#
#         #hovercard a.nyt-button-actions:hover {
#             background:#3C6791;
#             color:#fff !important;
#             text-decoration: none !important;
#         }
#
#         #hovercard a.nyt-button-actions.highlightButton:link,
#         #hovercard a.nyt-button-actions.highlightButton:visited {
#             color:#fff !important;
#             background:#3C6791;
#             text-decoration: none !important;
#         }
#
#
#         a.split-all-button {
#             background: #f3f3f4;
#             width:200px;
#             height: 30px;
#             position: absolute;
#             bottom: 0px;
#             font:11px "nyt-franklin", "Helvetica Neue", Arial, sans-serif;
#             font-weight: 700;
#             line-height: 30px;
#             color:#000 !important;
#             margin:0;
#             border: 1px solid #CCC;
#             text-align: center;
#             vertical-align: middle;
#             /*text-decoration: underline !important;*/
#         }
#
#         #hovercard a.split-all-button:hover{
#             background:#ffffff;
#             color:#004276 !important;
#             text-decoration: underline !important;
#         }
#         /* WEBKIT ONLY RULES */
#         @media screen and (-webkit-min-device-pixel-ratio:0) {
#             #masthead #hovercard {
#                 margin-left: -42px !important;
#             }
#         }
#         /* EXCLUDING NYT4 INTERACTIVES */
#         #interactiveABC #bar1-3panel {
#             display: none;
#         }
#     </style>
# <li id="bar1-3panel" class="bar1simplify__var1__markup user-subscriptions-menu user-subscriptions-group bar1_hover">
#     <a data-campaign-id="1" id="nyt-button-sub" class="" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&opzn&page=homepage.nytimes.com/index.html&pos=Bar1&sn2=5b35bc29/49f095e7&sn1=aa2aa18e/6816dae&camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&ad=nyt2014_bar1_simplify_ctrl_full_ad&goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp87JHJ%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D3Q64Y" target="_blank" data-content-collection="B1NYTNow_Apr1" data-content-placement="1">Subscribe Now</a>
#
#     <div id="hovercard">
#         <div id="top-panels">
#             <div class="hdclick split split-offer">
#                 <div class="split-content">
#                     <h3 class="hover-title">
#                         <a data-cmp-id="2" target="_blank" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&opzn&page=homepage.nytimes.com/index.html&pos=Bar1&sn2=5b35bc29/49f095e7&sn1=c8cf6684/49c6fc07&camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&ad=nyt2014_bar1_simplify_ctrl_full_ad&goto=https%3A%2F%2Fwww%2Enytimesathome%2Ecom%2Fhd%2F205%3FMediaCode%3DWB7AA%26CMP%3D3Q869" data-content-collection="B1NYTNow_Apr1" data-content-placement="">Home Delivery</a>
#                     </h3>
#
#                     <p class="hover-subhead">
#                         <a data-cmp-id="2" target="_blank" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&opzn&page=homepage.nytimes.com/index.html&pos=Bar1&sn2=5b35bc29/49f095e7&sn1=c8cf6684/49c6fc07&camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&ad=nyt2014_bar1_simplify_ctrl_full_ad&goto=https%3A%2F%2Fwww%2Enytimesathome%2Ecom%2Fhd%2F205%3FMediaCode%3DWB7AA%26CMP%3D3Q869" data-content-collection="B1NYTNow_Apr1" data-content-placement="">Newspaper delivery &#43; free,<br>unlimited digital access</a>
#                     </p>
#                 </div>
#             </div>
#
#             <div><hr></div>
#
#             <div class="digiclick split split-offer">
#                 <div class="split-content">
#                     <h3 class="hover-title">
#                         <a data-campaign-id="3" target="_blank" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&opzn&page=homepage.nytimes.com/index.html&pos=Bar1&sn2=5b35bc29/49f095e7&sn1=aa2aa18e/6816dae&camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&ad=nyt2014_bar1_simplify_ctrl_full_ad&goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp5558%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D3Q86F" data-content-collection="B1NYTNow_Apr1" data-content-placement="">Digital</a>
#                     </h3>
#                     <p class="hover-subhead">
#                         <a data-campaign-id="3" target="_blank" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&opzn&page=homepage.nytimes.com/index.html&pos=Bar1&sn2=5b35bc29/49f095e7&sn1=aa2aa18e/6816dae&camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&ad=nyt2014_bar1_simplify_ctrl_full_ad&goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp5558%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D3Q86F" data-content-collection="B1NYTNow_Apr1" data-content-placement="">Unlimited access to NYTimes.com<br>&#43; NYTimes mobile apps</a>
#                     </p>
#                 </div>
#             </div>
#
#             <div><hr></div>
#
#             <div class="nytnowclick split split-offer">
#                 <div class="split-content">
#                     <h3 class="hover-title">
#                         <a data-campaign-id="4" target="_blank" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&opzn&page=homepage.nytimes.com/index.html&pos=Bar1&sn2=5b35bc29/49f095e7&sn1=aa2aa18e/6816dae&camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&ad=nyt2014_bar1_simplify_ctrl_full_ad&goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp83KF8%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D44YQL" data-content-collection="B1NYTNow_Apr1" data-content-placement="">NYT Now</a>
#                     </h3>
#                     <p class="hover-subhead">
#                         <a data-campaign-id="4" target="_blank" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&opzn&page=homepage.nytimes.com/index.html&pos=Bar1&sn2=5b35bc29/49f095e7&sn1=aa2aa18e/6816dae&camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&ad=nyt2014_bar1_simplify_ctrl_full_ad&goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp83KF8%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D44YQL" data-content-collection="B1NYTNow_Apr1" data-content-placement="">Access top stories on<br>NYTimes.com &#43; the NYT Now app</a>
#                     </p>
#                 </div>
#             </div>
#         </div>
#
#         <div class="split split-all">
#             <a data-campaign-id="5" class="seeallclick split-all-button" target="_blank" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&opzn&page=homepage.nytimes.com/index.html&pos=Bar1&sn2=5b35bc29/49f095e7&sn1=aa2aa18e/6816dae&camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&ad=nyt2014_bar1_simplify_ctrl_full_ad&goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp87JHJ%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D466Q6" data-content-collection="B1NYTNow_Apr1" data-content-placement="2">See All Subscriptions</a>
#         </div>
#
#     </div>
# </li>
#
# <style class="bar1simplify__var2__style" type="text/css">
#         .NYT5Style .masthead-tools #bar1-3panel  {
#             display: inline;
#             vertical-align: top;
#         }
#         #bar1-3panel {
#             border:none;
#             position: relative;
#         }
#         .bar1_hover {
#             opacity: 0;
#         }
#         .sub_small_hide{
#             display: none;
#         }
#
#         #bar1-3panel > a {
#             -moz-box-sizing: border-box;
#             background-color: #6288A5;
#             border: 1px solid #4D7B9F;
#             border-radius: 3px;
#             color: #FFFFFF !important;
#             display: inline-block;
#             font-size: 1em;
#             font-weight: bold;
#             font-family: nyt-franklin,nyt-franklin-1,'Helvetica Neue',Arial,sans-serif;
#             padding: 7px 10px 6px;
#             text-transform: uppercase;
#             text-decoration: none;
#         }
#         #bar1-3panel > a:hover {
#             background-color: #326891;
#             border: 1px solid #265E8B;
#             text-decoration: none;
#         }
#         #hovercard {
#             width: 345px;
#             height: 208px;
#             display:none;
#             margin-left: -50px;
#             z-index: 99999999;
#             background-color:#fff;
#             border:1px solid #ccc;
#             border-radius: 3px;
#             position:absolute;
#             left: -120%;
#             top: 30px;
#             text-align:left;
#             -moz-box-shadow: 0 0 5px #888;
#             -webkit-box-shadow: 0 0 5px#888;
#             box-shadow: 0 0 5px #888;
#             white-space: normal;
#             display: none;
#         }
#         @media screen and (-webkit-min-device-pixel-ratio:0) {
#             /* CSS Statements that only apply on webkit-based browsers (Chrome, Safari, etc.) */
#             #hovercard {
#                 top: 35px;
#             }
#         }
#         #top-panels {
#             width: 335px;
#             height: 176px;
#             background-color:#fff;
#             border-radius: 3px;
#             position:absolute;
#             padding: 4px;
#         }
#
#         #hovercard:before {
#             content:url(http://graphics8.nytimes.com/marketing/bar1jsimages/arrowup.png);
#             position:absolute;
#             left: 180px;
#             top: -16px;
#             width: 140px;
#             height: 18px;
#             display:block;
#             text-align: center;
#             z-index: 1;
#         }
#
#         .split-content {
#             padding-top: 6px;
#             padding-left: 12px;
#         }
#         .split-offer {
#             min-width: 300px;
#             padding: 0;
#             min-height: 50px;
#             /*border-bottom: 1px solid #e9e9e9;*/
#             position: relative;
#         }
#         .split-offer:hover {
#             background-color:#f7f8f8;
#         }
#
#         #hovercard hr {
#             margin: 4px;
#             width: 320px;
#             color: #e3e3e3;
#         }
#
#         .hover-subhead {
#             font-family: 'nyt-franklin', 'Helvetica Neue', Arial, sans-serif;
#             font-weight: 400;
#             font-size: 11px;
#             line-height: 13px;
#             color: #333;
#             margin: 1px 0 0;
#             width: 180px;
#             position: absolute;
#             top: 10px;
#         }
#
#         #hovercard h3 a,
#         #hovercard p a {
#             color:#000 !important;
#             text-decoration: none;
#             display: block;
#         }
#
#         a.nyt-button-actions {
#             background: #F7F7F5;
#             color: #58595b !important;
#             width: 126px;
#             -webkit-border-radius:3px;
#             -moz-border-radius:3px;
#             border-radius:3px;
#             border:1px solid #ccc !important;
#             text-transform: uppercase;
#             font-weight: 400;
#             font:11px "nyt-franklin", "Helvetica Neue", Arial, sans-serif;
#             text-align: center;
#             padding:8px 0;
#             cursor: pointer;
#             display: block;
#             position: absolute;
#             left: 200px;
#             top: 10px;
#             text-decoration: none !important;
#         }
#
#
#         #hovercard a.nyt-button-actions:hover {
#             background:#3C6791;
#             color:#fff !important;
#             text-decoration: none !important;
#         }
#
#         #hovercard a.nyt-button-actions.highlightButton:link,
#         #hovercard a.nyt-button-actions.highlightButton:visited {
#             color:#fff !important;
#             background:#3C6791;
#             text-decoration: none !important;
#         }
#
#
#         a.split-all-button {
#             background: #f3f3f4;
#             width:345px;
#             height: 30px;
#             position: absolute;
#             bottom: 0px;
#             font:11px "nyt-franklin", "Helvetica Neue", Arial, sans-serif;
#             font-weight: 700;
#             line-height: 30px;
#             color:#000 !important;
#             margin:0;
#             border: 1px solid #CCC;
#             text-align: center;
#             vertical-align: middle;
#             /*text-decoration: underline !important;*/
#         }
#
#         #hovercard a.split-all-button:hover{
#             background:#ffffff;
#             color:#004276 !important;
#             text-decoration: underline !important;
#         }
#         /* WEBKIT ONLY RULES */
#         @media screen and (-webkit-min-device-pixel-ratio:0) {
#             #masthead #hovercard {
#                 margin-left: -42px !important;
#             }
#         }
#         /* EXCLUDING NYT4 INTERACTIVES */
#         #interactiveABC #bar1-3panel {
#             display: none;
#         }
#     </style>
# <li id="bar1-3panel" class="bar1simplify__var2__markup user-subscriptions-menu user-subscriptions-group bar1_hover">
#     <a data-campaign-id="1" id="nyt-button-sub" class="" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&opzn&page=homepage.nytimes.com/index.html&pos=Bar1&sn2=5b35bc29/49f095e7&sn1=aa2aa18e/6816dae&camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&ad=nyt2014_bar1_simplify_ctrl_full_ad&goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp87JHJ%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D3Q64Y" target="_blank" data-content-collection="B1NYTNow_Apr1" data-content-placement="1">Subscribe Now</a>
#
#     <div id="hovercard">
#         <div id="top-panels">
#             <div class="hdclick split split-offer">
#                 <div class="split-content">
#                     <p class="hover-subhead">
#                         <a data-cmp-id="2" target="_blank" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&opzn&page=homepage.nytimes.com/index.html&pos=Bar1&sn2=5b35bc29/49f095e7&sn1=c8cf6684/49c6fc07&camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&ad=nyt2014_bar1_simplify_ctrl_full_ad&goto=https%3A%2F%2Fwww%2Enytimesathome%2Ecom%2Fhd%2F205%3FMediaCode%3DWB7AA%26CMP%3D3Q869" data-content-collection="B1NYTNow_Apr1" data-content-placement="">Want both newspaper delivery and free, unlimited digital access?</a>
#                     </p>
#                     <a data-cmp-id="2" class="nyt-button-actions bar1button" target="_blank" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&opzn&page=homepage.nytimes.com/index.html&pos=Bar1&sn2=5b35bc29/49f095e7&sn1=c8cf6684/49c6fc07&camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&ad=nyt2014_bar1_simplify_ctrl_full_ad&goto=https%3A%2F%2Fwww%2Enytimesathome%2Ecom%2Fhd%2F205%3FMediaCode%3DWB7AA%26CMP%3D3Q869" data-content-collection="B1NYTNow_Apr0" data-content-placement="">Try Home Delivery</a>
#                 </div>
#             </div>
#
#             <div><hr></div>
#
#             <div class="digiclick split split-offer">
#                 <div class="split-content">
#                     <p class="hover-subhead">
#                         <a data-campaign-id="3" target="_blank" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&opzn&page=homepage.nytimes.com/index.html&pos=Bar1&sn2=5b35bc29/49f095e7&sn1=aa2aa18e/6816dae&camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&ad=nyt2014_bar1_simplify_ctrl_full_ad&goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp5558%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D3Q86F" data-content-collection="B1NYTNow_Apr1" data-content-placement="">Want unlimited access to NYTimes.com and our apps?</a>
#                     </p>
#                     <a data-campaign-id="3" class="nyt-button-actions bar1button" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&opzn&page=homepage.nytimes.com/index.html&pos=Bar1&sn2=5b35bc29/49f095e7&sn1=aa2aa18e/6816dae&camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&ad=nyt2014_bar1_simplify_ctrl_full_ad&goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp5558%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D3Q86F" target="_blank" data-content-collection="B1NYTNow_Apr0" data-content-placement="">Try Digital</a>
#                 </div>
#             </div>
#
#             <div><hr></div>
#
#             <div class="nytnowclick split split-offer">
#                 <div class="split-content">
#                     <p class="hover-subhead">
#                         <a data-campaign-id="4" target="_blank" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&opzn&page=homepage.nytimes.com/index.html&pos=Bar1&sn2=5b35bc29/49f095e7&sn1=aa2aa18e/6816dae&camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&ad=nyt2014_bar1_simplify_ctrl_full_ad&goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp83KF8%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D44YQL" data-content-collection="B1NYTNow_Apr1" data-content-placement="">Want access to top stories on NYTimes.com and the NYT Now app?</a>
#                     </p>
#                     <a data-campaign-id="4" class="nyt-button-actions bar1button" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&opzn&page=homepage.nytimes.com/index.html&pos=Bar1&sn2=5b35bc29/49f095e7&sn1=aa2aa18e/6816dae&camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&ad=nyt2014_bar1_simplify_ctrl_full_ad&goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp83KF8%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D44YQL" target="_blank" data-content-collection="B1NYTNow_Apr0" data-content-placement="">Try NYT Now</a>
#                 </div>
#             </div>
#         </div>
#
#         <div class="split split-all">
#             <a data-campaign-id="5" class="seeallclick split-all-button" target="_blank" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&opzn&page=homepage.nytimes.com/index.html&pos=Bar1&sn2=5b35bc29/49f095e7&sn1=aa2aa18e/6816dae&camp=nyt2014_bar1_simplify_ctrl_3Q64Y_3Q869_3Q86F_44YQL&ad=nyt2014_bar1_simplify_ctrl_full_ad&goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Fsubscriptions%2FMultiproduct%2Flp87JHJ%2Ehtml%3Fadxc%3D245408%26adxa%3D371526%26page%3Dhomepage.nytimes.com/index.html%26pos%3DBar1%26campaignId%3D466Q6" data-content-collection="B1NYTNow_Apr1" data-content-placement="2">See All Subscriptions</a>
#         </div>
#
#     </div>
# </li>
# </script>
# <li><a href="/auth/login?URI=http://">Log In</a></li>
# <li><a href="/gst/regi.html" onclick="dcsMultiTrack('WT.z_ract', 'Regnow', 'WT.z_rprod', 'Masthead','WT.z_dcsm','1');">Register Now</a></li>
# </ul>
# <div class="mainTabsContainer tabsContainer">
# <ul class="mainTabs tabs" id="mainTabs">
# <li class="first"><a href="http://www.nytimes.com/pages/todayspaper/index.html">Today's Paper</a></li>
# <li><a href="http://video.nytimes.com/">Video</a></li>
# <li><a href="http://www.nytimes.com/mostpopular">Most Popular</a></li>
# </ul>
# </div><!--close .tabsContainer -->
# <div class="editionToggle" id="editionToggle">
# Edition: <span id="editionToggleUS"><a href="http://www.nytimes.com" onclick="NYTD.EditionPref.setUS();" onmousedown="dcsMultiTrack('DCS.dcssip','www.nytimes.com','DCS.dcsuri','/toggleIHTtoNYT.html','WT.ti','toggleIHTtoNYT','WT.z_dcsm','1');">U.S.</a></span> / <span id="editionToggleGlobal"><a href="http://global.nytimes.com" onclick="NYTD.EditionPref.setGlobal();" onmousedown="dcsMultiTrack('DCS.dcssip','www.nytimes.com','DCS.dcsuri','/toggleNYTtoIHT.html','WT.ti','toggleNYTtoIHT','WT.z_dcsm','1');">Global</a></span>
# </div><!--close editionToggle -->
# <div class="tabContent active" id="page">
# <div id="masthead">
# <div class="singleAd" id="TopLeft">
# <!-- ADXINFO classification="Share_of_Voice_Tile_-_Left" campaign="Marc_Jacob_1927517_2014-nyt8" priority="8500" isInlineSafe="N" width="184" height="90" --><a href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=TopLeft&amp;sn2=ab8a95f5/87622a3f&amp;sn1=240133a8/2803b20f&amp;camp=Marc_Jacob_1927517_2014-nyt8&amp;ad=Marc_Jacobs_LEFT_Swimwear_May7&amp;goto=http%3A%2F%2Fwww%2Emarcjacobs%2Ecom%2Fmarc%2Dby%2Dmarc%2Djacobs%2Fwomens%2Fswim%2F%3Futm%5Fsource%3Dnyt14%26utm%5Fmedium%3Dlefttile%26utm%5Fcampaign%3Dmayswim" target="_blank">
# <img border="0" height="90" src="http://graphics8.nytimes.com/adx/images/ADS/37/30/ad.373010/SS14_SWIM_NYT_LEFT.jpg" width="184"/></a>
# </div>
# <div class="singleAd" id="TopRight">
# <!-- ADXINFO classification="Share_of_Voice_Tile_-_Right" campaign="Marc_Jacob_1927517_2014-nyt8" priority="8500" isInlineSafe="N" width="184" height="90" --><a href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=TopRight&amp;sn2=361d9a2f/d5c54928&amp;sn1=10300de0/7db095a1&amp;camp=Marc_Jacob_1927517_2014-nyt8&amp;ad=Marc_Jacobs_RIGHT_Swimwear_May7&amp;goto=http%3A%2F%2Fwww%2Emarcjacobs%2Ecom%2Fmarc%2Dby%2Dmarc%2Djacobs%2Fwomens%2Fswim%2F%3Futm%5Fsource%3Dnyt14%26utm%5Fmedium%3Drighttile%26utm%5Fcampaign%3Dmayswim" target="_blank">
# ...
# </td>
# </tr>
# <tr>
# <td style="padding-right: 0;  padding-top: 7px; padding-left: 5px;" width="40%">
# <a href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=HPBottom1&amp;sn2=ba5a7590/f9c69a68&amp;sn1=30d7fcf5/c8501541&amp;camp=nyt2014_journeysmodule_timesjourneys_hp_us&amp;ad=timesjourneys_brand&amp;goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Ftimes%2Djourneys%2Fjourney%2Dfinder%2F%3Futm%5Fsource%3Dnytimes%26utm%5Fmedium%3Dhome%5Fpage%5Fmodule%26utm%5Fterm%3Dspy%5Fcapitals%5Fred%5Fsquare%26utm%5Fcontent%3Dpic%5Fsingle%26utm%5Fcampaign%3Dbrand%5Flaunch" target="_blank"><img alt="Times Journeys" src="http://graphics8.nytimes.com/adx/images/ADS/37/02/ad.370255/ad-copy-3-brand.jpg" style="height: 150px; width: 150px;"/></a>
# </td>
# <td style="padding-right: 0; position: relative; vertical-align: text-top;" width="60%">
# <div style="margin-top: 10px; margin-bottom:5px;">
# <a class="itemHeader" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=HPBottom1&amp;sn2=ba5a7590/f9c69a68&amp;sn1=30d7fcf5/c8501541&amp;camp=nyt2014_journeysmodule_timesjourneys_hp_us&amp;ad=timesjourneys_brand&amp;goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Ftimes%2Djourneys%2Fjourney%2Dfinder%2F%3Futm%5Fsource%3Dnytimes%26utm%5Fmedium%3Dhome%5Fpage%5Fmodule%26utm%5Fterm%3Dnew%5Fzealand%5Fspy%5Fcapitals%5Fitaly%26utm%5Fcontent%3Dbody%5Fcopy%26utm%5Fcampaign%3Dbrand%5Flaunch" target="_blank">Travel Inspired by Our Journalism</a>
# </div>
# <div style="margin-top: 5px; margin-bottom:5px;">
# <a class="itemDescription" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=HPBottom1&amp;sn2=ba5a7590/f9c69a68&amp;sn1=30d7fcf5/c8501541&amp;camp=nyt2014_journeysmodule_timesjourneys_hp_us&amp;ad=timesjourneys_brand&amp;goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Ftimes%2Djourneys%2F%3Futm%5Fsource%3Dnytimes%26utm%5Fmedium%3Dhome%5Fpage%5Fmodule%26utm%5Fterm%3Dtj%5Furl%26utm%5Fcontent%3Durl%26utm%5Fcampaign%3Dbrand%5Flaunch" style="font-weight: 700;" target="_blank">"Join Times-selected specialists"</a>
# </div>
# <div><a class="itemDescription" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=HPBottom1&amp;sn2=ba5a7590/f9c69a68&amp;sn1=30d7fcf5/c8501541&amp;camp=nyt2014_journeysmodule_timesjourneys_hp_us&amp;ad=timesjourneys_brand&amp;goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Ftimes%2Djourneys%2Fjourney%2Dfinder%2F%3Futm%5Fsource%3Dnytimes%26utm%5Fmedium%3Dhome%5Fpage%5Fmodule%26utm%5Fterm%3Dnew%5Fzealand%5Fspy%5Fcapitals%5Fitaly%26utm%5Fcontent%3Dbody%5Fcopy%26utm%5Fcampaign%3Dbrand%5Flaunch" target="_blank">
# <strong>DEPARTING SOON:</strong>
# <ul class="itemDescription">
# <li class="itemDescription"><strong>New Zealand:</strong> Hike across glaciers</li>
# <li class="itemDescription"><strong>Spy Capitals:</strong> Join a former CIA agent</li>
# <li class="itemDescription"><strong>Italy:</strong> Ferraris, Vistas &amp; Vineyards</li>
# </ul>
# </a></div>
# <div style="margin-top: 18px;">
# <a class="journeysLink" href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=HPBottom1&amp;sn2=ba5a7590/f9c69a68&amp;sn1=30d7fcf5/c8501541&amp;camp=nyt2014_journeysmodule_timesjourneys_hp_us&amp;ad=timesjourneys_brand&amp;goto=http%3A%2F%2Fwww%2Enytimes%2Ecom%2Ftimes%2Djourneys%2F%3Futm%5Fsource%3Dnytimes%26utm%5Fmedium%3Dhome%5Fpage%5Fmodule%26utm%5Fterm%3Dtj%5Furl%26utm%5Fcontent%3Durl%26utm%5Fcampaign%3Dbrand%5Flaunch" target="_blank">Nytimes.com/timesjourneys »</a>
# </div>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# <div class="columnGroup ">
# </div>
# <div class="columnGroup ">
# <div class="columnGroup fullWidth">
# <div class="singleRuleDivider insetH"></div>
# <div class="subColumn-2 wrap">
# <div class="column">
# <div class="columnGroup centeredAd">
# </div>
# </div>
# <div class="column last">
# <div class="columnGroup centeredAd">
# <div id="Box2"><!-- ADXINFO classification="Broker_Button" campaign="nyt2014_120x90_NYTStore_evergreen" priority="1000" isInlineSafe="N" width="120" height="90" --><a href="http://www.nytimes.com/adx/bin/adx_click.html?type=goto&amp;opzn&amp;page=homepage.nytimes.com/index.html&amp;pos=Box2&amp;sn2=5b35dc2a/56c295e7&amp;sn1=622ecbbc/c00dc0a3&amp;camp=nyt2014_120x90_NYTStore_evergreen&amp;ad=120x90_NYTStore_evergreen&amp;goto=http%3A%2F%2Fwww%2Enytstore%2Ecom%3Futm%5Fsource%3Dnytimes%26utm%5Fmedium%3Dhouse%2Dad%26utm%5Fterm%3D120x90%26utm%5Fcontent%3Devergreen%26utm%5Fcampaign%3D05%2D2014" target="_blank">
# <img border="0" height="90" src="http://graphics8.nytimes.com/adx/images/ADS/37/24/ad.372454/120x90.jpg" width="120">
# </img></a></div>
# </div>
# </div>
# </div><!--end .subColumn-2 wrap -->
# </div><!--end .columnGroup fullWidth -->
# </div>
# <div class="columnGroup last">
# </div>
# </div><!--close cColumn -->
# </div><!--close spanAB -->
# </div><!--close column -->
# </div><!--close doubleRule -->
# </div><!--close baseLayout -->
# <!--close main -->
# <footer class="pageFooter">
# <div class="inset">
# <nav class="pageFooterNav">
# <ul class="pageFooterNavList wrap">
# <li class="firstItem"><a href="http://www.nytco.com/">© 2014 The New York Times Company</a></li>
# <li><a href="http://spiderbites.nytimes.com/">Site Map</a></li>
# <li><a href="http://www.nytimes.com/privacy">Privacy</a></li>
# <li><a href="http://www.nytimes.com/ref/membercenter/help/privacy.html#pp">Your Ad Choices</a></li>
# <li><a href="http://www.nytimes.whsites.net/mediakit/">Advertise</a></li>
# <li><a href="http://www.nytimes.com/content/help/rights/sale/terms-of-sale.html ">Terms of Sale</a></li>
# <li><a href="http://www.nytimes.com/ref/membercenter/help/agree.html">Terms of Service</a></li>
# <li><a href="http://www.nytco.com/careers">Work With Us</a></li>
# <li><a href="http://www.nytimes.com/rss">RSS</a></li>
# <li><a href="http://www.nytimes.com/membercenter/sitehelp.html">Help</a></li>
# <li><a href="http://www.nytimes.com/ref/membercenter/help/infoservdirectory.html">Contact Us</a></li>
# <li class="lastItem"><a href="/membercenter/feedback.html">Site Feedback</a></li>
# </ul>
# </nav>
# </div><!--close inset -->
# </footer><!--close pageFooter -->
# <!--close page -->
# <!--close shell -->
# <script language="JavaScript" type="text/javascript">
#     var NYTArticleCommentCounts = {"http:\/\/movies.nytimes.com\/movie\/458370\/The-Revenant\/overview":{"count":0,"commentsEnabled":true,"assetUrl":"http:\/\/movies.nytimes.com\/movie\/458370\/The-Revenant\/overview"},"http:\/\/www.nytimes.com\/2014\/05\/12\/sports\/soccer\/city-is-the-last-club-standing-on-a-field-of-broken-dreams.html":{"count":0,"commentsEnabled":true,"assetUrl":"http:\/\/www.nytimes.com\/2014\/05\/12\/sports\/soccer\/city-is-the-last-club-standing-on-a-field-of-broken-dreams.html"},"http:\/\/www.nytimes.com\/2014\/05\/12\/world\/europe\/ukraine-referendum.html":{"count":12,"commentsEnabled":true,"assetUrl":"http:\/\/www.nytimes.com\/2014\/05\/12\/world\/europe\/ukraine-referendum.html"},"http:\/\/www.nytimes.com\/2014\/05\/11\/fashion\/Robin-Roberts-Good-Morning-America-Television.html":{"count":5,"commentsEnabled":true,"assetUrl":"http:\/\/www.nytimes.com\/2014\/05\/11\/fashion\/Robin-Roberts-Good-Morning-America-Television.html"},"http:\/\/www.nytimes.com\/2014\/05\/11\/magazine\/who-made-that-stun-gun.html":{"count":1,"commentsEnabled":true,"assetUrl":"http:\/\/www.nytimes.com\/2014\/05\/11\/magazine\/who-made-that-stun-gun.html"},"http:\/\/movies.nytimes.com\/movie\/104035\/Nightmare\/overview":{"count":0,"commentsEnabled":true,"assetUrl":"http:\/\/movies.nytimes.com\/movie\/104035\/Nightmare\/overview"},"http:\/\/www.nytimes.com\/2014\/05\/11\/nyregion\/new-york-police-recruit-muslims-to-be-informers.html":{"count":255,"commentsEnabled":true,"assetUrl":"http:\/\/www.nytimes.com\/2014\/05\/11\/nyregion\/new-york-police-recruit-muslims-to-be-informers.html"},"http:\/\/www.nytimes.com\/2014\/05\/11\/business\/a-soldiers-war-on-pain.html":{"count":113,"commentsEnabled":true,"assetUrl":"http:\/\/www.nytimes.com\/2014\/05\/11\/business\/a-soldiers-war-on-pain.html"},"http:\/\/www.nytimes.com\/2014\/05\/11\/opinion\/sunday\/the-marriage-plot.html":{"count":35,"commentsEnabled":true,"assetUrl":"http:\/\/www.nytimes.com\/2014\/05\/11\/opinion\/sunday\/the-marriage-plot.html"},"http:\/\/www.nytimes.com\/2014\/05\/11\/upshot\/the-polarized-court.html":{"count":361,"commentsEnabled":true,"assetUrl":"http:\/\/www.nytimes.com\/2014\/05\/11\/upshot\/the-polarized-court.html"},"http:\/\/www.nytimes.com\/2014\/05\/11\/sports\/football\/michael-sam-picked-by-st-louis-rams-in-nfl-draft.html":{"count":158,"commentsEnabled":true,"assetUrl":"http:\/\/www.nytimes.com\/2014\/05\/11\/sports\/football\/michael-sam-picked-by-st-louis-rams-in-nfl-draft.html"},"http:\/\/www.nytimes.com\/2014\/05\/11\/sports\/baseball\/bid-for-no-hitter-in-texas-is-sullied-before-its-spoiled.html":{"count":7,"commentsEnabled":true,"assetUrl":"http:\/\/www.nytimes.com\/2014\/05\/11\/sports\/baseball\/bid-for-no-hitter-in-texas-is-sullied-before-its-spoiled.html"},"http:\/\/www.nytimes.com\/2014\/05\/11\/world\/asia\/china-says-goodbye-in-the-key-of-g-kenny-g.html":{"count":109,"commentsEnabled":true,"assetUrl":"http:\/\/www.nytimes.com\/2014\/05\/11\/world\/asia\/china-says-goodbye-in-the-key-of-g-kenny-g.html"},"http:\/\/movies.nytimes.com\/movie\/471686\/Neighbors\/overview":{"count":0,"commentsEnabled":true,"assetUrl":"http:\/\/movies.nytimes.com\/movie\/471686\/Neighbors\/overview"},"http:\/\/www.nytimes.com\/2014\/05\/11\/opinion\/sunday\/when-music-was-strange.html":{"count":93,"commentsEnabled":true,"assetUrl":"http:\/\/www.nytimes.com\/2014\/05\/11\/opinion\/sunday\/when-music-was-strange.html"},"http:\/\/www.nytimes.com\/2014\/05\/11\/opinion\/sunday\/the-rise-of-antibiotic-resistance.html":{"count":221,"commentsEnabled":true,"assetUrl":"http:\/\/www.nytimes.com\/2014\/05\/11\/opinion\/sunday\/the-rise-of-antibiotic-resistance.html"},"http:\/\/movies.nytimes.com\/movie\/461726\/Legends-of-Oz-Dorothy-s-Return\/overview":{"count":0,"commentsEnabled":true,"assetUrl":"http:\/\/movies.nytimes.com\/movie\/461726\/Legends-of-Oz-Dorothy-s-Return\/overview"},"http:\/\/www.nytimes.com\/2014\/05\/11\/opinion\/sunday\/lost-booksellers-of-new-york.htm ...
# <img class="hidden" height="1" src="/adx/bin/clientside/77912415Q2F______Q3F_Q3FQ27Q7EaQ272Q3FQ3F(________Q3F0Q27WI2st(__Q60a_IlH(IQ60" width="3">
# <!-- ADXINFO classification="Text_Link" campaign="nyt2014_circgroup_cookie_dropper" priority="9200" isInlineSafe="N" width="0" height="0" --><script>document.cookie='circgroup=digi;domain=.nytimes.com;path=/;max-age=' + 60 * 60 * 24;</script>
# <script id="nytnowurls" language="javascript" type="application/json">{"NytNow":{"urls":["http:\/\/www.nytimes.com\/2014\/05\/12\/sports\/baseball\/yankees-place-cc-sabathia-on-disabled-list.html","http:\/\/www.nytimes.com\/2014\/05\/12\/sports\/soccer\/city-is-the-last-club-standing-on-a-field-of-broken-dreams.html","http:\/\/www.nytimes.com\/2014\/05\/12\/world\/middleeast\/deadly-barracks-attackin-iraq.html","http:\/\/www.nytimes.com\/2014\/05\/12\/business\/international\/samsungs-chairman-has-surgery-after-heart-attack.html","http:\/\/www.nytimes.com\/2014\/05\/12\/world\/europe\/ukraine-referendum.html","http:\/\/www.nytimes.com\/2014\/05\/12\/world\/asia\/abdullah-abdullah-afghanistan-presidential-election-coalition.html","http:\/\/www.nytimes.com\/2014\/05\/12\/world\/asia\/vietnam.html","http:\/\/www.nytimes.com\/aponline\/2014\/05\/11\/us\/ap-us-arizona-plane-crash.html","http:\/\/www.nytimes.com\/2014\/05\/11\/us\/lem-johns-who-guarded-vice-president-lyndon-b-johnson-in-dallas-dies-at-88.html","http:\/\/www.nytimes.com\/2014\/05\/11\/nyregion\/new-york-police-recruit-muslims-to-be-informers.html","http:\/\/www.nytimes.com\/2014\/05\/11\/sports\/football\/michael-sam-picked-by-st-louis-rams-in-nfl-draft.html","http:\/\/www.nytimes.com\/2014\/05\/11\/upshot\/the-polarized-court.html","http:\/\/www.nytimes.com\/2014\/05\/11\/world\/asia\/china-says-goodbye-in-the-key-of-g-kenny-g.html","http:\/\/www.nytimes.com\/interactive\/2014\/05\/09\/upshot\/when-politics-approach-the-bench.html","http:\/\/www.nytimes.com\/2014\/05\/11\/world\/europe\/merkel-and-hollande-send-russia-a-warning.html","http:\/\/www.nytimes.com\/2014\/05\/11\/us\/in-a-first-two-women-tie-the-knot-in-arkansas.html","http:\/\/www.nytimes.com\/2014\/05\/11\/world\/asia\/in-indian-candidate-hindu-right-sees-a-reawakening.html","http:\/\/www.nytimes.com\/2014\/05\/11\/world\/asia\/disease-of-pakistans-poor-now-worries-the-affluent.html","http:\/\/www.nytimes.com\/2014\/05\/11\/world\/americas\/stowaways-are-stranded-in-mexico-by-train-ban.html","http:\/\/www.nytimes.com\/2014\/05\/11\/world\/europe\/russia-ratchets-up-ukraines-gas-bills-in-shift-to-an-economic-battlefield.html","http:\/\/www.nytimes.com\/2014\/05\/11\/opinion\/sunday\/the-rise-of-antibiotic-resistance.html","http:\/\/www.nytimes.com\/2014\/05\/11\/us\/a-state-sized-just-right-to-contain-its-pride.html","http:\/\/www.nytimes.com\/2014\/05\/11\/opinion\/sunday\/friedman-more-chopsticks-please.html","http:\/\/www.nytimes.com\/2014\/05\/11\/opinion\/sunday\/dowd-with-malice-toward-nuns.html","http:\/\/www.nytimes.com\/2014\/05\/11\/sports\/filling-pages-not-difficult-with-a-life-lived-large.html","http:\/\/www.nytimes.com\/2014\/05\/11\/us\/brothers-work-different-angles-in-taking-on-climate-change.html","http:\/\/www.nytimes.com\/2014\/05\/11\/business\/a-soldiers-war-on-pain.html","http:\/\/www.nytimes.com\/2014\/05\/11\/world\/europe\/a-hard-sell-to-tame-a-name-in-spain.html","http:\/\/www.nytimes.com\/2014\/05\/11\/business\/defending-the-open-internet.html","http:\/\/www.nytimes.com\/2014\/05\/11\/us\/politics\/pennsylvania-governor-faces-an-uphill-battle-for-a-second-term.html","http:\/\/www.nytimes.com\/2014\/05\/11\/world\/middleeast\/in-yemen-a-counterterrorism-challenge.html","http:\/\/www.nytimes.com\/2014\/05\/11\/sports\/basketball\/clippers-for-sale-and-the-owner-who-was-desperate.html","http:\/\/www.nytimes.com\/2014\/05\/11\/world\/europe\/managing-every-detail-separatists-prepare-for-voting-in-eastern-ukraine.html","http:\/\/www.nytimes.com\/2014\/05\/11\/us\/virginia-balloon-crash.html","http:\/\/www.nytimes.com\/2014\/05\/11\/world\/middleeast\/yemen-silent-on-disclosure-of-shooting-by-americans.html","http:\/\/www.nytimes.com\/2014\/05\/11\/us\/reading-writing-arithmetic-and-lately-coding.html","http:\/\/www.nytimes.com\/2014\/05\/11\/health\/a-simple-theory-and-a-proposal-on-hiv-in-africa.html","http:\/\/www.nytimes.com\/2014\/05\/11\/nyregion\/remains-of-9-11-victims-are- ...
# </script>
# <script src="http://js.nyt.com/js2/build/homepage/bottom.js" type="text/javascript"></script>
# <!-- Start UPT call -->
# <img border="0" height="1" src="http://up.nytimes.com/?d=0/1/&amp;t=1&amp;s=0&amp;ui=&amp;r=&amp;u=www%2enytimes%2ecom%2f%3f" width="3">
# <!-- End UPT call -->
# <script language="JavaScript"><!--
#           var dcsvid="";
#           var regstatus="non-registered";
#         //--></script>
# <script src="http://graphics8.nytimes.com/js/app/analytics/trackingTags_v1.1.js" type="text/javascript"></script>
# <noscript>
# <div><img alt="DCSIMG" height="1" id="DCSIMG" src="http://wt.o.nytimes.com/dcsym57yw10000s1s8g0boozt_9t1x/njs.gif?dcsuri=/nojavascript&amp;WT.js=No&amp;WT.tv=1.0.7" width="1"/></div>
# </noscript>
# </img></img>

# %%
soup = soup.find_all('a')

# %%
text = [link.text.strip() for link in soup if link.text and link.text.strip()]
text
# Out:
# [u'Subscribe Now',
#  u'Try Home Delivery for 50% Off 12 Weeks Plus Free All Digital Access',
#  u'All print options include free, unlimited access to NYTimes.com, NYTimes apps and NYT Now.',
#  u'Get Home Delivery',
#  u'Try a Digital Subscription Today for Just 99\xa2 for Your First 4 Weeks',
#  u'Get unlimited access to NYTimes.com, NYTimes apps,plus free NYT Now.',
#  u'Get Digital',
#  u'Try NYT Now and Get Your First 4 Weeks Free',
#  u'A selection of top stories,handpicked by editors. Available on NYTimes.com and a new iPhone\xae app.',
#  u'Get NYT Now',
#  u'See All Subscriptions',
#  u'Subscribe',
#  u'Log In',
#  u'Register Now',
#  u"Today's Paper",
#  u'Video',
#  u'Most Popular',
#  u'U.S.',
#  u'Global',
#  u'Personalize Your Weather',
#  u'World',
#  u'U.S.',
#  u'Politics',
#  u'New York',
#  u'Business',
#  u'Dealbook',
#  u'Technology',
#  u'Sports',
#  u'Science',
#  u'Health',
#  u'Arts',
#  u'Style',
#  u'Opinion',
#  u'Autos',
#  u'Blogs',
#  u'Books',
#  u'Cartoons',
#  u'Classifieds',
#  u'Crosswords',
#  u'Dining & Wine',
#  u'Education',
#  u'Event Guide',
#  u'Fashion & Style',
#  u'Home & Garden',
#  u'Jobs',
#  u'Magazine',
#  u'Media',
#  u'Movies',
#  u'Music',
#  u'Obituaries',
#  u'Public Editor',
#  u'Real Estate',
#  u'Sunday Review',
#  u'T Magazine',
#  u'Television',
#  u'Theater',
#  u'Travel',
#  u'Weddings / Celebrations',
#  u'Interactives',
#  u'Photography',
#  u'Video',
#  u'Alerts',
#  u'Beta 620',
#  u'Corrections',
#  u'Mobile',
#  u'Movie Tickets',
#  u'Learning Network',
#  u'Newsletters',
#  u'NYT Events',
#  u'NYT Store',
#  u'Theater Tickets',
#  u'Times Machine',
#  u'Times Skimmer',
#  u'Times Topics',
#  u'Times Wire',
#  u'Home Delivery',
#  u'Digital Subscriptions',
#  u'Gift Subscriptions',
#  u'Corporate Subscriptions',
#  u'Education Rate',
#  u'Crosswords',
#  u'Home Delivery Customer Care',
#  u'Replica Edition',
#  u'INYT Home Delivery',
#  u'About NYT Co.',
#  u'Advertise',
#  u'New York Police Recruit Muslims to Be Informers on Terrorism',
#  u'2 Yemenis Shot by Americans Are Linked to Al Qaeda',
#  u'Steady Turnout of\nReferendum Voters\nin Eastern Ukraine',
#  u'Map: Rebels and Loyalists Vie for Control',
#  u'U.S. Tourists Book Fewer Russian Trips Amid Strife',
#  u'A Simple Theory, and a Proposal, on H.I.V. in Africa',
#  u'Video',
#  u'The Morning Muse of Television',
#  u'The Women of New York\u2019s City Hall',
#  u'Affordable Housing Plan Built on Assumptions',
#  u'The Paradox of Art as Work',
#  u'Reading, Writing, Arithmetic, and Lately, Coding',
#  u'Yankees Place C.C. Sabathia on Disabled List',
#  u'20 Iraqi Soldiers Killed in Barracks Attack',
#  u'Samsung Chairman Suffers Heart Attack',
#  u'Coalition for Front-Runner in Afghan Vote',
#  u'Brothers Battle Climate Change on Two Fronts',
#  u'Video \xbb',
#  u'More Video \xbb',
#  u'previous',
#  u'next',
#  u'A Nanny\u2019s Love',
#  u'News from A.P.',
#  u'Reuters',
#  u'Secret Service Sent White House Patrol to Check Employee: Report',
#  u"Church Attacks in Israel 'Poison' Before Pope's Visit, Cleric Says",
#  u'Italy Grapples With Specter of Corruption as EU Vote Nears',
#  u'Russian Official Delivers Petition From Moldova Region to Join Russia',
#  u'Please, Mother, Enough',
#  u'Op-Art: Mom Genes',
#  u'Editorial: The Rise of Antibiotic Resistance',
#  u'Bruni: Lessons in Catholic Judgment',
#  u'Douthat: Rape and the College Brand',
#  u'Dowd: With Malice Toward Nuns',
#  u'Friedman: More Chopsticks, Please',
#  u'Kristof: What\u2019s So Scary About Smart Girls?',
#  u'An Alluring Song, Echoed Through 8 Summers',
#  u'Caribbean Camping: A Mother-Daughter Trip',
#  u'Today\u2019s Times Insider',
#  u'A College Admissions Essay Recalled',
#  u"Deciding On the Book Review's Cover",
#  u'Business Day\xa0\xbb',
#  u'Defending the Open Internet',
#  u'Sports\xa0\xbb',
#  u'Clippers for Sale, and the Owner Who Was Desperate',
#  u'City Survives a Field of Broken Dreams',
#  u'Music \xbb',
#  u'Michael Jackson Returns, at Least on Record',
#  u'N.Y. / Region \xbb',
#  u'They\u2019re Stompin\u2019 on Avenue B',
#  u'Sunday Review \xbb',
#  u'The Strip: Microstrikes for the Modern Workforce',
#  u'Travel \xbb',
#  u'A Working Vacation on an Umbrian Farm',
#  u'PAID POST\n\nSuffering From Infobesity?',
#  u'Sunday Review \xbb',
#  u'Editorial: Health Care Showdown in Virginia',
#  u'Theater \xbb',
#  u'Tony Awards: Grab a Dream and Sing Out',
#  u'Magazine \xbb',
#  u'Addict. Informant. Mother.',
#  u'T MAGAZINE \xbb',
#  u'T Summer Travel Issue',
#  u'Sunday Review \xbb',
#  u'Opinion: The Toxic Brew in Our Yards',
#  u'Fashion & Style \xbb',
#  u'Weddings and Celebrations',
#  u'Sunday Review \xbb',
#  u'Op-Art: Mom Genes',
#  u'Movies \xbb',
#  u'The Paradox of Art as Work',
#  u'World  \xbb',
#  u'Steady Turnout of Early Voters in Eastern Ukraine',
#  u'Russia Ratchets Up Ukraine\u2019s Gas Bills in Shift to an Economic Battlefield',
#  u'Merkel and Hollande Send Russia a Warning',
#  u'Business Day \xbb',
#  u'A Soldier\u2019s War on Pain',
#  u'Defending the Open Internet',
#  u'Russia Ratchets Up Ukraine\u2019s Gas Bills in Shift to an Economic Battlefield',
#  u'Opinion \xbb',
#  u'Opinion: Advice for a Troubled Teen',
#  u"Today's Editorials: The Rise of Antibiotic Resistance",
#  u'Op-Ed Columnist: Lessons in Catholic Judgment',
#  u'U.S. \xbb',
#  u'Reading, Writing, Arithmetic, and Lately, Coding',
#  u'Brothers Battle Climate Change on Two Fronts',
#  u'Pennsylvania Governor Faces an Uphill Battle for a Second Term',
#  u'Technology \xbb',
#  u'Defending the Open Internet',
#  u'Reading, Writing, Arithmetic, and Lately, Coding',
#  u'Bits Blog: The Peril of Knowledge Everywhere',
#  u'Arts \xbb',
#  u'Grab a Dream and Sing Out',
#  u'A Finger Wag in Good Hands',
#  u'The Unconventional Earn Their Applause',
#  u'Politics  \xbb',
#  u'Pennsylvania Governor Faces an Uphill Battle for a Second Term',
#  u'Brothers Battle Climate Change on Two Fronts',
#  u'First Lady Condemns Abduction of Nigerian Schoolgirls',
#  u'Sports \xbb',
#  u'On Soccer: City Is the Last Club Standing on a Field of Broken Dreams',
#  u'The Premier League Standings if Only Goals by English Players Counted',
#  u'Clippers for Sale, and the Owner Who Was Desperate',
#  u'Movies \xbb',
#  u'Cross Cuts: The Paradox of Art as Work',
#  u'Just Can\u2019t Get Enough of Each Other',
#  u'Face-Lift? Well, You Still Look Like Hell',
#  u'N.Y. / Region  \xbb',
#  u'New York Police Recruit Muslims to Be Informers',
#  u'The Women of New York\u2019s City Hall',
#  u'Fairy Tale Romances, Real and Staged',
#  u'Obituaries \xbb',
#  u'Lem Johns, Who Guarded Johnson in Dallas, Dies at 88',
#  u'Joe Wilder, Horn Player, Dies at 92; Elegance Was His Theme Song',
#  u'Maria Lassnig, Painter of Self From the Inside Out, Dies at 94',
#  u'Theater \xbb',
#  u'Grab a Dream and Sing Out',
#  u'And the Nominees Should Be ...',
#  u'And the Nominees Should Be ...',
#  u'Science  \xbb',
#  u'Brothers Battle Climate Change on Two Fronts',
#  u'Reading, Writing, Arithmetic, and Lately, Coding',
#  u'A Simple Theory, and a Proposal, on H.I.V. in Africa',
#  u'Travel \xbb',
#  u'A Working Vacation on an Umbrian Farm',
#  u'Echoes of History at a Tuscan Estate',
#  u'Update: U.S. Trips to Russia Fall Amid Conflict',
#  u'Television \xbb',
#  u'Bedeviled Anew by a Pregnancy',
#  u'The 11th Most Fascinating Person Ever',
#  u'His Psyche Lurks Inside His Scripts',
#  u'Health \xbb',
#  u'A Simple Theory, and a Proposal, on H.I.V. in Africa',
#  u'Samsung\u2019s Chairman Has Cardiac Procedure After Heart Attack',
#  u'Disease of Pakistan\u2019s Poor Now Worries the Affluent',
#  u'Dining & Wine \xbb',
#  u'A Good Appetite: Taking Advantage of Sorrel\u2019s Brief Life',
#  u'City Kitchen: Green Garlic Stirs a Pot of Chicken Soup',
#  u'Last Stop, Last Drop: Metro-North Bar Cars Chug Into History',
#  u'Books \xbb',
#  u'Pledges of Allegiance',
#  u'Cradle of Civil Disobedience',
#  u'Glare of a Gilded Age',
#  u'Education \xbb',
#  u'Reading, Writing, Arithmetic, and Lately, Coding',
#  u'Internationall Educcation: In New Textbook, the Story of Singapore Begins 500 Years Earlier',
#  u'Beliefs: At Evangelical Colleges, Leadership Is Often the Family Business',
#  u'Home & Garden \xbb',
#  u'The Details: Your Hand in Marriage',
#  u'Grandma Never Had It So Good',
#  u'On Location: Harbour Island, The Bahamas: Redefining a Beach Share',
#  u'Sunday Review \xbb',
#  u'Op-Ed Columnist: Rape and the College Brand',
#  u'Dispatch: In Rwanda, Finding Echoes of Germany',
#  u'Editorial: Real Goal of Abortion \u2018Limits\u2019: Bans',
#  u'Real Estate \xbb',
#  u'The Hamptons-in-Waiting',
#  u'Big Deal: Your Building on an Index Card',
#  u'Exclusive: Upper West Side Brownstone With Modern Twists',
#  u'Fashion & Style \xbb',
#  u'The Morning Muse of Television',
#  u'The Time of the Tummy',
#  u'Raising a Style Icon',
#  u'Magazine \xbb',
#  u'Masala Dosa to Die For',
#  u'Addict. Informant. Mother.',
#  u'What Timothy Geithner Really Thinks',
#  u'Automobiles \xbb',
#  u'Behind the Wheel: Silence Is Golden, and Priced Accordingly',
#  u'Owners Who Are Happy When the Engine Doesn\u2019t Start',
#  u'The Future Will See You Now',
#  u'T Magazine \xbb',
#  u'Now Online | Summer Travel Issue',
#  u'Editor\u2019s Letter | Simple Pleasures',
#  u'In the Air | Tribal Beauty',
#  u'The Upshot \xbb',
#  u'The Upshot: The Polarized Court',
#  u'The Upshot: A Possible Path to Closing the Pay Gap',
#  u'The Upshot: A Drink as Complicated as Motherhood',
#  u'Real Estate',
#  u'Autos',
#  u'Jobs',
#  u'All Classifieds',
#  u'The Hamptons-in-Waiting',
#  u'Go to Real Estate Section',
#  u'Search for Properties',
#  u'Download the Real Estate App',
#  u'Commercial Real Estate',
#  u'Video Showcase: Real Estate',
#  u'Post an Ad',
#  u'Sprawling 2 BedroomRentals Start at $4995Stunning Views',
#  u'Place a Classified Ad \xbb',
#  u'The Future Will See You Now',
#  u'New Car Reviews',
#  u'Used Car Information',
#  u'Collectible Cars',
#  u'Sell Your Car',
#  u'Sprawling 2 BedroomRentals Start at $4995Stunning Views',
#  u'Place a Classified Ad \xbb',
#  u'A Different View on Risk and Reward',
#  u'Advanced Search \xbb',
#  u'Post Your Resum\xe9 to NYTimes.com/monster',
#  u'Find a Job by Industry',
#  u'Post a Job Online and in Print',
#  u'Search R\xe9sum\xe9s',
#  u'See All Recruitment Options',
#  u'Sprawling 2 BedroomRentals Start at $4995Stunning Views',
#  u'Place a Classified Ad \xbb',
#  u'Autos',
#  u'Business Directory',
#  u'Camps & Schools',
#  u'Commercial Real Estate',
#  u'Home & Garden Directory',
#  u'Jobs',
#  u'Social Announcements',
#  u'Residental Real Estate',
#  u'Small Inns & Lodges',
#  u'Weddings Directory',
#  u'Post a Classified Ad Online',
#  u'In Print',
#  u'Place a Classified Ad \xbb',
#  u'Times Wire \xbb',
#  u'See More \xbb',
#  u'Manchester City\u2019s Coach: Honest, Charming and Winning With Style',
#  u'Yankees Place C.C. Sabathia on Disabled List',
#  u'Hamilton Holds Off Rosberg at Spanish Grand Prix',
#  u'Travel Inspired by Our Journalism',
#  u'"Join Times-selected specialists"',
#  u'DEPARTING SOON:\n\nNew Zealand: Hike across glaciers\nSpy Capitals: Join a former CIA agent\nItaly: Ferraris, Vistas & Vineyards',
#  u'Nytimes.com/timesjourneys \xbb',
#  u'\xa9 2014 The New York Times Company',
#  u'Site Map',
#  u'Privacy',
#  u'Your Ad Choices',
#  u'Advertise',
#  u'Terms of Sale',
#  u'Terms of Service',
#  u'Work With Us',
#  u'RSS',
#  u'Help',
#  u'Contact Us',
#  u'Site Feedback']

# %%
words = []
for phrase in text:
    if ' ' in phrase:
        words += phrase.split(' ')
    else:
        words.append(phrase)
words
# Out:
# [u'Subscribe',
#  u'Now',
#  u'Try',
#  u'Home',
#  u'Delivery',
#  u'for',
#  u'50%',
#  u'Off',
#  u'12',
#  u'Weeks',
#  u'Plus',
#  u'Free',
#  u'All',
#  u'Digital',
#  u'Access',
#  u'All',
#  u'print',
#  u'options',
#  u'include',
#  u'free,',
#  u'unlimited',
#  u'access',
#  u'to',
#  u'NYTimes.com,',
#  u'NYTimes',
#  u'apps',
#  u'and',
#  u'NYT',
#  u'Now.',
#  u'Get',
#  u'Home',
#  u'Delivery',
#  u'Try',
#  u'a',
#  u'Digital',
#  u'Subscription',
#  u'Today',
#  u'for',
#  u'Just',
#  u'99\xa2',
#  u'for',
#  u'Your',
#  u'First',
#  u'4',
#  u'Weeks',
#  u'Get',
#  u'unlimited',
#  u'access',
#  u'to',
#  u'NYTimes.com,',
#  u'NYTimes',
#  u'apps,plus',
#  u'free',
#  u'NYT',
#  u'Now.',
#  u'Get',
#  u'Digital',
#  u'Try',
#  u'NYT',
#  u'Now',
#  u'and',
#  u'Get',
#  u'Your',
#  u'First',
#  u'4',
#  u'Weeks',
#  u'Free',
#  u'A',
#  u'selection',
#  u'of',
#  u'top',
#  u'stories,handpicked',
#  u'by',
#  u'editors.',
#  u'Available',
#  u'on',
#  u'NYTimes.com',
#  u'and',
#  u'a',
#  u'new',
#  u'iPhone\xae',
#  u'app.',
#  u'Get',
#  u'NYT',
#  u'Now',
#  u'See',
#  u'All',
#  u'Subscriptions',
#  u'Subscribe',
#  u'Log',
#  u'In',
#  u'Register',
#  u'Now',
#  u"Today's",
#  u'Paper',
#  u'Video',
#  u'Most',
#  u'Popular',
#  u'U.S.',
#  u'Global',
#  u'Personalize',
#  u'Your',
#  u'Weather',
#  u'World',
#  u'U.S.',
#  u'Politics',
#  u'New',
#  u'York',
#  u'Business',
#  u'Dealbook',
#  u'Technology',
#  u'Sports',
#  u'Science',
#  u'Health',
#  u'Arts',
#  u'Style',
#  u'Opinion',
#  u'Autos',
#  u'Blogs',
#  u'Books',
#  u'Cartoons',
#  u'Classifieds',
#  u'Crosswords',
#  u'Dining',
#  u'&',
#  u'Wine',
#  u'Education',
#  u'Event',
#  u'Guide',
#  u'Fashion',
#  u'&',
#  u'Style',
#  u'Home',
#  u'&',
#  u'Garden',
#  u'Jobs',
#  u'Magazine',
#  u'Media',
#  u'Movies',
#  u'Music',
#  u'Obituaries',
#  u'Public',
#  u'Editor',
#  u'Real',
#  u'Estate',
#  u'Sunday',
#  u'Review',
#  u'T',
#  u'Magazine',
#  u'Television',
#  u'Theater',
#  u'Travel',
#  u'Weddings',
#  u'/',
#  u'Celebrations',
#  u'Interactives',
#  u'Photography',
#  u'Video',
#  u'Alerts',
#  u'Beta',
#  u'620',
#  u'Corrections',
#  u'Mobile',
#  u'Movie',
#  u'Tickets',
#  u'Learning',
#  u'Network',
#  u'Newsletters',
#  u'NYT',
#  u'Events',
#  u'NYT',
#  u'Store',
#  u'Theater',
#  u'Tickets',
#  u'Times',
#  u'Machine',
#  u'Times',
#  u'Skimmer',
#  u'Times',
#  u'Topics',
#  u'Times',
#  u'Wire',
#  u'Home',
#  u'Delivery',
#  u'Digital',
#  u'Subscriptions',
#  u'Gift',
#  u'Subscriptions',
#  u'Corporate',
#  u'Subscriptions',
#  u'Education',
#  u'Rate',
#  u'Crosswords',
#  u'Home',
#  u'Delivery',
#  u'Customer',
#  u'Care',
#  u'Replica',
#  u'Edition',
#  u'INYT',
#  u'Home',
#  u'Delivery',
#  u'About',
#  u'NYT',
#  u'Co.',
#  u'Advertise',
#  u'New',
#  u'York',
#  u'Police',
#  u'Recruit',
#  u'Muslims',
#  u'to',
#  u'Be',
#  u'Informers',
#  u'on',
#  u'Terrorism',
#  u'2',
#  u'Yemenis',
#  u'Shot',
#  u'by',
#  u'Americans',
#  u'Are',
#  u'Linked',
#  u'to',
#  u'Al',
#  u'Qaeda',
#  u'Steady',
#  u'Turnout',
#  u'of\nReferendum',
#  u'Voters\nin',
#  u'Eastern',
#  u'Ukraine',
#  u'Map:',
#  u'Rebels',
#  u'and',
#  u'Loyalists',
#  u'Vie',
#  u'for',
#  u'Control',
#  u'U.S.',
#  u'Tourists',
#  u'Book',
#  u'Fewer',
#  u'Russian',
#  u'Trips',
#  u'Amid',
#  u'Strife',
#  u'A',
#  u'Simple',
#  u'Theory,',
#  u'and',
#  u'a',
#  u'Proposal,',
#  u'on',
#  u'H.I.V.',
#  u'in',
#  u'Africa',
#  u'Video',
#  u'The',
#  u'Morning',
#  u'Muse',
#  u'of',
#  u'Television',
#  u'The',
#  u'Women',
#  u'of',
#  u'New',
#  u'York\u2019s',
#  u'City',
#  u'Hall',
#  u'Affordable',
#  u'Housing',
#  u'Plan',
#  u'Built',
#  u'on',
#  u'Assumptions',
#  u'The',
#  u'Paradox',
#  u'of',
#  u'Art',
#  u'as',
#  u'Work',
#  u'Reading,',
#  u'Writing,',
#  u'Arithmetic,',
#  u'and',
#  u'Lately,',
#  u'Coding',
#  u'Yankees',
#  u'Place',
#  u'C.C.',
#  u'Sabathia',
#  u'on',
#  u'Disabled',
#  u'List',
#  u'20',
#  u'Iraqi',
#  u'Soldiers',
#  u'Killed',
#  u'in',
#  u'Barracks',
#  u'Attack',
#  u'Samsung',
#  u'Chairman',
#  u'Suffers',
#  u'Heart',
#  u'Attack',
#  u'Coalition',
#  u'for',
#  u'Front-Runner',
#  u'in',
#  u'Afghan',
#  u'Vote',
#  u'Brothers',
#  u'Battle',
#  u'Climate',
#  u'Change',
#  u'on',
#  u'Two',
#  u'Fronts',
#  u'Video',
#  u'\xbb',
#  u'More',
#  u'Video',
#  u'\xbb',
#  u'previous',
#  u'next',
#  u'A',
#  u'Nanny\u2019s',
#  u'Love',
#  u'News',
#  u'from',
#  u'A.P.',
#  u'Reuters',
#  u'Secret',
#  u'Service',
#  u'Sent',
#  u'White',
#  u'House',
#  u'Patrol',
#  u'to',
#  u'Check',
#  u'Employee:',
#  u'Report',
#  u'Church',
#  u'Attacks',
#  u'in',
#  u'Israel',
#  u"'Poison'",
#  u'Before',
#  u"Pope's",
#  u'Visit,',
#  u'Cleric',
#  u'Says',
#  u'Italy',
#  u'Grapples',
#  u'With',
#  u'Specter',
#  u'of',
#  u'Corruption',
#  u'as',
#  u'EU',
#  u'Vote',
#  u'Nears',
#  u'Russian',
#  u'Official',
#  u'Delivers',
#  u'Petition',
#  u'From',
#  u'Moldova',
#  u'Region',
#  u'to',
#  u'Join',
#  u'Russia',
#  u'Please,',
#  u'Mother,',
#  u'Enough',
#  u'Op-Art:',
#  u'Mom',
#  u'Genes',
#  u'Editorial:',
#  u'The',
#  u'Rise',
#  u'of',
#  u'Antibiotic',
#  u'Resistance',
#  u'Bruni:',
#  u'Lessons',
#  u'in',
#  u'Catholic',
#  u'Judgment',
#  u'Douthat:',
#  u'Rape',
#  u'and',
#  u'the',
#  u'College',
#  u'Brand',
#  u'Dowd:',
#  u'With',
#  u'Malice',
#  u'Toward',
#  u'Nuns',
#  u'Friedman:',
#  u'More',
#  u'Chopsticks,',
#  u'Please',
#  u'Kristof:',
#  u'What\u2019s',
#  u'So',
#  u'Scary',
#  u'About',
#  u'Smart',
#  u'Girls?',
#  u'An',
#  u'Alluring',
#  u'Song,',
#  u'Echoed',
#  u'Through',
#  u'8',
#  u'Summers',
#  u'Caribbean',
#  u'Camping:',
#  u'A',
#  u'Mother-Daughter',
#  u'Trip',
#  u'Today\u2019s',
#  u'Times',
#  u'Insider',
#  u'A',
#  u'College',
#  u'Admissions',
#  u'Essay',
#  u'Recalled',
#  u'Deciding',
#  u'On',
#  u'the',
#  u'Book',
#  u"Review's",
#  u'Cover',
#  u'Business',
#  u'Day\xa0\xbb',
#  u'Defending',
#  u'the',
#  u'Open',
#  u'Internet',
#  u'Sports\xa0\xbb',
#  u'Clippers',
#  u'for',
#  u'Sale,',
#  u'and',
#  u'the',
#  u'Owner',
#  u'Who',
#  u'Was',
#  u'Desperate',
#  u'City',
#  u'Survives',
#  u'a',
#  u'Field',
#  u'of',
#  u'Broken',
#  u'Dreams',
#  u'Music',
#  u'\xbb',
#  u'Michael',
#  u'Jackson',
#  u'Returns,',
#  u'at',
#  u'Least',
#  u'on',
#  u'Record',
#  u'N.Y.',
#  u'/',
#  u'Region',
#  u'\xbb',
#  u'They\u2019re',
#  u'Stompin\u2019',
#  u'on',
#  u'Avenue',
#  u'B',
#  u'Sunday',
#  u'Review',
#  u'\xbb',
#  u'The',
#  u'Strip:',
#  u'Microstrikes',
#  u'for',
#  u'the',
#  u'Modern',
#  u'Workforce',
#  u'Travel',
#  u'\xbb',
#  u'A',
#  u'Working',
#  u'Vacation',
#  u'on',
#  u'an',
#  u'Umbrian',
#  u'Farm',
#  u'PAID',
#  u'POST\n\nSuffering',
#  u'From',
#  u'Infobesity?',
#  u'Sunday',
#  u'Review',
#  u'\xbb',
#  u'Editorial:',
#  u'Health',
#  u'Care',
#  u'Showdown',
#  u'in',
#  u'Virginia',
#  u'Theater',
#  u'\xbb',
#  u'Tony',
#  u'Awards:',
#  u'Grab',
#  u'a',
#  u'Dream',
#  u'and',
#  u'Sing',
#  u'Out',
#  u'Magazine',
#  u'\xbb',
#  u'Addict.',
#  u'Informant.',
#  u'Mother.',
#  u'T',
#  u'MAGAZINE',
#  u'\xbb',
#  u'T',
#  u'Summer',
#  u'Travel',
#  u'Issue',
#  u'Sunday',
#  u'Review',
#  u'\xbb',
#  u'Opinion:',
#  u'The',
#  u'Toxic',
#  u'Brew',
#  u'in',
#  u'Our',
#  u'Yards',
#  u'Fashion',
#  u'&',
#  u'Style',
#  u'\xbb',
#  u'Weddings',
#  u'and',
#  u'Celebrations',
#  u'Sunday',
#  u'Review',
#  u'\xbb',
#  u'Op-Art:',
#  u'Mom',
#  u'Genes',
#  u'Movies',
#  u'\xbb',
#  u'The',
#  u'Paradox',
#  u'of',
#  u'Art',
#  u'as',
#  u'Work',
#  u'World',
#  u'',
#  u'\xbb',
#  u'Steady',
#  u'Turnout',
#  u'of',
#  u'Early',
#  u'Voters',
#  u'in',
#  u'Eastern',
#  u'Ukraine',
#  u'Russia',
#  u'Ratchets',
#  u'Up',
#  u'Ukraine\u2019s',
#  u'Gas',
#  u'Bills',
#  u'in',
#  u'Shift',
#  u'to',
#  u'an',
#  u'Economic',
#  u'Battlefield',
#  u'Merkel',
#  u'and',
#  u'Hollande',
#  u'Send',
#  u'Russia',
#  u'a',
#  u'Warning',
#  u'Business',
#  u'Day',
#  u'\xbb',
#  u'A',
#  u'Soldier\u2019s',
#  u'War',
#  u'on',
#  u'Pain',
#  u'Defending',
#  u'the',
#  u'Open',
#  u'Internet',
#  u'Russia',
#  u'Ratchets',
#  u'Up',
#  u'Ukraine\u2019s',
#  u'Gas',
#  u'Bills',
#  u'in',
#  u'Shift',
#  u'to',
#  u'an',
#  u'Economic',
#  u'Battlefield',
#  u'Opinion',
#  u'\xbb',
#  u'Opinion:',
#  u'Advice',
#  u'for',
#  u'a',
#  u'Troubled',
#  u'Teen',
#  u"Today's",
#  u'Editorials:',
#  u'The',
#  u'Rise',
#  u'of',
#  u'Antibiotic',
#  u'Resistance',
#  u'Op-Ed',
#  u'Columnist:',
#  u'Lessons',
#  u'in',
#  u'Catholic',
#  u'Judgment',
#  u'U.S.',
#  u'\xbb',
#  u'Reading,',
#  u'Writing,',
#  u'Arithmetic,',
#  u'and',
#  u'Lately,',
#  u'Coding',
#  u'Brothers',
#  u'Battle',
#  u'Climate',
#  u'Change',
#  u'on',
#  u'Two',
#  u'Fronts',
#  u'Pennsylvania',
#  u'Governor',
#  u'Faces',
#  u'an',
#  u'Uphill',
#  u'Battle',
#  u'for',
#  u'a',
#  u'Second',
#  u'Term',
#  u'Technology',
#  u'\xbb',
#  u'Defending',
#  u'the',
#  u'Open',
#  u'Internet',
#  u'Reading,',
#  u'Writing,',
#  u'Arithmetic,',
#  u'and',
#  u'Lately,',
#  u'Coding',
#  u'Bits',
#  u'Blog:',
#  u'The',
#  u'Peril',
#  u'of',
#  u'Knowledge',
#  u'Everywhere',
#  u'Arts',
#  u'\xbb',
#  u'Grab',
#  u'a',
#  u'Dream',
#  u'and',
#  u'Sing',
#  u'Out',
#  u'A',
#  u'Finger',
#  u'Wag',
#  u'in',
#  u'Good',
#  u'Hands',
#  u'The',
#  u'Unconventional',
#  u'Earn',
#  u'Their',
#  u'Applause',
#  u'Politics',
#  u'',
#  u'\xbb',
#  u'Pennsylvania',
#  u'Governor',
#  u'Faces',
#  u'an',
#  u'Uphill',
#  u'Battle',
#  u'for',
#  u'a',
#  u'Second',
#  u'Term',
#  u'Brothers',
#  u'Battle',
#  u'Climate',
#  u'Change',
#  u'on',
#  u'Two',
#  u'Fronts',
#  u'First',
#  u'Lady',
#  u'Condemns',
#  u'Abduction',
#  u'of',
#  u'Nigerian',
#  u'Schoolgirls',
#  u'Sports',
#  u'\xbb',
#  u'On',
#  u'Soccer:',
#  u'City',
#  u'Is',
#  u'the',
#  u'Last',
#  u'Club',
#  u'Standing',
#  u'on',
#  u'a',
#  u'Field',
#  u'of',
#  u'Broken',
#  u'Dreams',
#  u'The',
#  u'Premier',
#  u'League',
#  u'Standings',
#  u'if',
#  u'Only',
#  u'Goals',
#  u'by',
#  u'English',
#  u'Players',
#  u'Counted',
#  u'Clippers',
#  u'for',
#  u'Sale,',
#  u'and',
#  u'the',
#  u'Owner',
#  u'Who',
#  u'Was',
#  u'Desperate',
#  u'Movies',
#  u'\xbb',
#  u'Cross',
#  u'Cuts:',
#  u'The',
#  u'Paradox',
#  u'of',
#  u'Art',
#  u'as',
#  u'Work',
#  u'Just',
#  u'Can\u2019t',
#  u'Get',
#  u'Enough',
#  u'of',
#  u'Each',
#  u'Other',
#  u'Face-Lift?',
#  u'Well,',
#  u'You',
#  u'Still',
#  u'Look',
#  u'Like',
#  u'Hell',
#  u'N.Y.',
#  u'/',
#  u'Region',
#  u'',
#  u'\xbb',
#  u'New',
#  u'York',
#  u'Police',
#  u'Recruit',
#  u'Muslims',
#  u'to',
#  u'Be',
#  u'Informers',
#  u'The',
#  u'Women',
#  u'of',
#  u'New',
#  u'York\u2019s',
#  u'City',
#  u'Hall',
#  u'Fairy',
#  u'Tale',
#  u'Romances,',
#  u'Real',
#  u'and',
#  u'Staged',
#  u'Obituaries',
#  u'\xbb',
#  u'Lem',
#  u'Johns,',
#  u'Who',
#  u'Guarded',
#  u'Johnson',
#  u'in',
#  u'Dallas,',
#  u'Dies',
#  u'at',
#  u'88',
#  u'Joe',
#  u'Wilder,',
#  u'Horn',
#  u'Player,',
#  u'Dies',
#  u'at',
#  u'92;',
#  u'Elegance',
#  u'Was',
#  u'His',
#  u'Theme',
#  u'Song',
#  u'Maria',
#  u'Lassnig,',
#  u'Painter',
#  u'of',
#  u'Self',
#  u'From',
#  u'the',
#  u'Inside',
#  u'Out,',
#  u'Dies',
#  u'at',
#  u'94',
#  u'Theater',
#  u'\xbb',
#  u'Grab',
#  u'a',
#  u'Dream',
#  u'and',
#  u'Sing',
#  u'Out',
#  u'And',
#  u'the',
#  u'Nominees',
#  u'Should',
#  u'Be',
#  u'...',
#  u'And',
#  u'the',
#  u'Nominees',
#  u'Should',
#  u'Be',
#  u'...',
#  u'Science',
#  u'',
#  u'\xbb',
#  u'Brothers',
#  u'Battle',
#  u'Climate',
#  u'Change',
#  u'on',
#  u'Two',
#  u'Fronts',
#  u'Reading,',
#  u'Writing,',
#  u'Arithmetic,',
#  u'and',
#  u'Lately,',
#  u'Coding',
#  u'A',
#  u'Simple',
#  u'Theory,',
#  u'and',
#  u'a',
#  u'Proposal,',
#  u'on',
#  u'H.I.V.',
#  u'in',
#  u'Africa',
#  u'Travel',
#  u'\xbb',
#  u'A',
#  u'Working',
#  u'Vacation',
#  u'on',
#  u'an',
#  u'Umbrian',
#  u'Farm',
#  u'Echoes',
#  u'of',
#  u'History',
#  u'at',
#  u'a',
#  u'Tuscan',
#  u'Estate',
#  u'Update:',
#  u'U.S.',
#  u'Trips',
#  u'to',
#  u'Russia',
#  u'Fall',
#  u'Amid',
#  u'Conflict',
#  u'Television',
#  u'\xbb',
#  u'Bedeviled',
#  u'Anew',
#  u'by',
#  u'a',
#  u'Pregnancy',
#  u'The',
#  u'11th',
#  u'Most',
#  u'Fascinating',
#  u'Person',
#  u'Ever',
#  u'His',
#  u'Psyche',
#  u'Lurks',
#  u'Inside',
#  u'His',
#  u'Scripts',
#  u'Health',
#  u'\xbb',
#  u'A',
#  u'Simple',
#  u'Theory,',
#  u'and',
#  u'a',
#  u'Proposal,',
#  u'on',
#  u'H.I.V.',
#  u'in',
#  u'Africa',
#  u'Samsung\u2019s',
#  u'Chairman',
#  u'Has',
#  u'Cardiac',
#  u'Procedure',
#  u'After',
#  u'Heart',
#  u'Attack',
#  u'Disease',
#  u'of',
#  u'Pakistan\u2019s',
#  u'Poor',
#  u'Now',
#  u'Worries',
#  u'the',
#  u'Affluent',
#  u'Dining',
#  u'&',
#  u'Wine',
#  u'\xbb',
#  u'A',
#  u'Good',
#  u'Appetite:',
#  u'Taking',
#  u'Advantage',
#  u'of',
#  u'Sorrel\u2019s',
#  u'Brief',
#  u'Life',
#  u'City',
#  u'Kitchen:',
#  u'Green',
#  u'Garlic',
#  u'Stirs',
#  u'a',
#  u'Pot',
#  u'of',
#  u'Chicken',
#  u'Soup',
#  u'Last',
#  u'Stop,',
#  u'Last',
#  u'Drop:',
#  u'Metro-North',
#  u'Bar',
#  u'Cars',
#  u'Chug',
#  u'Into',
#  u'History',
#  u'Books',
#  u'\xbb',
#  u'Pledges',
#  u'of',
#  u'Allegiance',
#  u'Cradle',
#  u'of',
#  u'Civil',
#  u'Disobedience',
#  u'Glare',
#  u'of',
#  u'a',
#  u'Gilded',
#  u'Age',
#  u'Education',
#  u'\xbb',
#  u'Reading,',
#  u'Writing,',
#  u'Arithmetic,',
#  u'and',
#  u'Lately,',
#  u'Coding',
#  u'Internationall',
#  u'Educcation:',
#  u'In',
#  u'New',
#  u'Textbook,',
#  u'the',
#  u'Story',
#  u'of',
#  u'Singapore',
#  u'Begins',
#  u'500',
#  u'Years',
#  u'Earlier',
#  u'Beliefs:',
#  u'At',
#  u'Evangelical',
#  u'Colleges,',
#  u'Leadership',
#  u'Is',
#  u'Often',
#  u'the',
#  u'Family',
#  u'Business',
#  u'Home',
#  u'&',
#  u'Garden',
#  u'\xbb',
#  u'The',
#  u'Details:',
#  u'Your',
#  u'Hand',
#  u'in',
#  u'Marriage',
#  u'Grandma',
#  u'Never',
#  u'Had',
#  u'It',
#  u'So',
#  u'Good',
#  u'On',
#  u'Location:',
#  u'Harbour',
#  u'Island,',
#  u'The',
#  u'Bahamas:',
#  u'Redefining',
#  u'a',
#  u'Beach',
#  u'Share',
#  u'Sunday',
#  u'Review',
#  u'\xbb',
#  u'Op-Ed',
#  u'Columnist:',
#  u'Rape',
#  u'and',
#  u'the',
#  u'College',
#  u'Brand',
#  u'Dispatch:',
#  u'In',
#  u'Rwanda,',
#  u'Finding',
#  u'Echoes',
#  u'of',
#  u'Germany',
#  u'Editorial:',
#  u'Real',
#  u'Goal',
#  u'of',
#  u'Abortion',
#  u'\u2018Limits\u2019:',
#  u'Bans',
#  u'Real',
#  u'Estate',
#  u'\xbb',
#  u'The',
#  u'Hamptons-in-Waiting',
#  u'Big',
#  u'Deal:',
#  u'Your',
#  u'Building',
#  u'on',
#  u'an',
#  u'Index',
#  u'Card',
#  u'Exclusive:',
#  u'Upper',
#  u'West',
#  u'Side',
#  u'Brownstone',
#  u'With',
#  u'Modern',
#  u'Twists',
#  u'Fashion',
#  u'&',
#  u'Style',
#  u'\xbb',
#  u'The',
#  u'Morning',
#  u'Muse',
#  u'of',
#  u'Television',
#  u'The',
#  u'Time',
#  u'of',
#  u'the',
#  u'Tummy',
#  u'Raising',
#  u'a',
#  u'Style',
#  u'Icon',
#  u'Magazine',
#  u'\xbb',
#  u'Masala',
#  u'Dosa',
#  u'to',
#  u'Die',
#  u'For',
#  u'Addict.',
#  u'Informant.',
#  u'Mother.',
#  u'What',
#  u'Timothy',
#  u'Geithner',
#  u'Really',
#  u'Thinks',
#  u'Automobiles',
#  u'\xbb',
#  u'Behind',
#  u'the',
#  u'Wheel:',
#  u'Silence',
#  u'Is',
#  u'Golden,',
#  u'and',
#  u'Priced',
#  u'Accordingly',
#  u'Owners',
#  u'Who',
#  u'Are',
#  u'Happy',
#  u'When',
#  u'the',
#  u'Engine',
#  u'Doesn\u2019t',
#  u'Start',
#  u'The',
#  u'Future',
#  u'Will',
#  u'See',
#  u'You',
#  u'Now',
#  u'T',
#  u'Magazine',
#  u'\xbb',
#  u'Now',
#  u'Online',
#  u'|',
#  u'Summer',
#  u'Travel',
#  u'Issue',
#  u'Editor\u2019s',
#  u'Letter',
#  u'|',
#  u'Simple',
#  u'Pleasures',
#  u'In',
#  u'the',
#  u'Air',
#  u'|',
#  u'Tribal',
#  u'Beauty',
#  u'The',
#  u'Upshot',
#  u'\xbb',
#  u'The',
#  u'Upshot:',
#  u'The',
#  u'Polarized',
#  u'Court',
#  u'The',
#  u'Upshot:',
#  u'A',
#  u'Possible',
#  u'Path',
#  u'to',
#  u'Closing',
#  u'the',
#  u'Pay',
#  u'Gap',
#  u'The',
#  u'Upshot:',
#  u'A',
#  u'Drink',
#  u'as',
#  u'Complicated',
#  u'as',
#  u'Motherhood',
#  u'Real',
#  u'Estate',
#  u'Autos',
#  u'Jobs',
#  u'All',
#  u'Classifieds',
#  u'The',
#  u'Hamptons-in-Waiting',
#  u'Go',
#  u'to',
#  u'Real',
#  u'Estate',
#  u'Section',
#  u'Search',
#  u'for',
#  u'Properties',
#  u'Download',
#  u'the',
#  u'Real',
#  u'Estate',
#  u'App',
#  u'Commercial',
#  u'Real',
#  u'Estate',
#  u'Video',
#  u'Showcase:',
#  u'Real',
#  u'Estate',
#  u'Post',
#  u'an',
#  u'Ad',
#  u'Sprawling',
#  u'2',
#  u'BedroomRentals',
#  u'Start',
#  u'at',
#  u'$4995Stunning',
#  u'Views',
#  u'Place',
#  u'a',
#  u'Classified',
#  u'Ad',
#  u'\xbb',
#  u'The',
#  u'Future',
#  u'Will',
#  u'See',
#  u'You',
#  u'Now',
#  u'New',
#  u'Car',
#  u'Reviews',
#  u'Used',
#  u'Car',
#  u'Information',
#  u'Collectible',
#  u'Cars',
#  u'Sell',
#  u'Your',
#  u'Car',
#  u'Sprawling',
#  u'2',
#  u'BedroomRentals',
#  u'Start',
#  u'at',
#  u'$4995Stunning',
#  u'Views',
#  u'Place',
#  u'a',
#  u'Classified',
#  u'Ad',
#  u'\xbb',
#  u'A',
#  u'Different',
#  u'View',
#  u'on',
#  u'Risk',
#  u'and',
#  u'Reward',
#  u'Advanced',
#  u'Search',
#  u'\xbb',
#  u'Post',
#  u'Your',
#  u'Resum\xe9',
#  u'to',
#  u'NYTimes.com/monster',
#  u'Find',
#  u'a',
#  u'Job',
#  u'by',
#  u'Industry',
#  u'Post',
#  u'a',
#  u'Job',
#  u'Online',
#  u'and',
#  u'in',
#  u'Print',
#  u'Search',
#  u'R\xe9sum\xe9s',
#  u'See',
#  u'All',
#  u'Recruitment',
#  u'Options',
#  u'Sprawling',
#  u'2',
#  u'BedroomRentals',
#  u'Start',
#  u'at',
#  u'$4995Stunning',
#  u'Views',
#  u'Place',
#  u'a',
#  u'Classified',
#  u'Ad',
#  u'\xbb',
#  u'Autos',
#  u'Business',
#  u'Directory',
#  u'Camps',
#  u'&',
#  u'Schools',
#  u'Commercial',
#  u'Real',
#  u'Estate',
#  u'Home',
#  u'&',
#  u'Garden',
#  u'Directory',
#  u'Jobs',
#  u'Social',
#  u'Announcements',
#  u'Residental',
#  u'Real',
#  u'Estate',
#  u'Small',
#  u'Inns',
#  u'&',
#  u'Lodges',
#  u'Weddings',
#  u'Directory',
#  u'Post',
#  u'a',
#  u'Classified',
#  u'Ad',
#  u'Online',
#  u'In',
#  u'Print',
#  u'Place',
#  u'a',
#  u'Classified',
#  u'Ad',
#  u'\xbb',
#  u'Times',
#  u'Wire',
#  u'\xbb',
#  u'See',
#  u'More',
#  u'\xbb',
#  u'Manchester',
#  u'City\u2019s',
#  u'Coach:',
#  u'Honest,',
#  u'Charming',
#  u'and',
#  u'Winning',
#  u'With',
#  u'Style',
#  u'Yankees',
#  u'Place',
#  u'C.C.',
#  u'Sabathia',
#  u'on',
#  u'Disabled',
#  u'List',
#  u'Hamilton',
#  u'Holds',
#  u'Off',
#  u'Rosberg',
#  u'at',
#  u'Spanish',
#  u'Grand',
#  u'Prix',
#  u'Travel',
#  u'Inspired',
#  u'by',
#  u'Our',
#  u'Journalism',
#  u'"Join',
#  u'Times-selected',
#  u'specialists"',
#  u'DEPARTING',
#  u'SOON:\n\nNew',
#  u'Zealand:',
#  u'Hike',
#  u'across',
#  u'glaciers\nSpy',
#  u'Capitals:',
#  u'Join',
#  u'a',
#  u'former',
#  u'CIA',
#  u'agent\nItaly:',
#  u'Ferraris,',
#  u'Vistas',
#  u'&',
#  u'Vineyards',
#  u'Nytimes.com/timesjourneys',
#  u'\xbb',
#  u'\xa9',
#  u'2014',
#  u'The',
#  u'New',
#  u'York',
#  u'Times',
#  u'Company',
#  u'Site',
#  u'Map',
#  u'Privacy',
#  u'Your',
#  u'Ad',
#  u'Choices',
#  u'Advertise',
#  u'Terms',
#  u'of',
#  u'Sale',
#  u'Terms',
#  u'of',
#  u'Service',
#  u'Work',
#  u'With',
#  u'Us',
#  u'RSS',
#  u'Help',
#  u'Contact',
#  u'Us',
#  u'Site',
#  u'Feedback']

# %%
counter = Counter(words).most_common()[-10:]
counter
# Out:
# [(u'Polarized', 1),
#  (u'Essay', 1),
#  (u'DEPARTING', 1),
#  (u'Rosberg', 1),
#  (u'Al', 1),
#  (u'An', 1),
#  (u'Well,', 1),
#  (u'At', 1),
#  (u'Spanish', 1),
#  (u'Chicken', 1)]

# %% [markdown]
# ## Graphing some data with matplotlib
# #### (from J.R. Johansson's tutorial)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from pylab import linspace

# %%
x = linspace(0, 100)
y = x ** 2

plt.figure(figsize=(12, 8))
plt.plot(x, y, 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.title('My x squared graph')
plt.show()

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib.pylab import meshgrid
from matplotlib.pylab import cos
from matplotlib.pylab import cm

alpha = 0.7
pi = 3.14

phi_ext = 2 * pi * 0.5

phi_m = linspace(0, 2*pi, 100)
phi_p = linspace(0, 2*pi, 100)

X,Y = meshgrid(phi_p, phi_m)

def flux_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2 * cos(phi_p)*cos(phi_m) - alpha * cos(phi_ext - 2*phi_p)

Z = flux_qubit_potential(X, Y).T

fig = plt.figure(figsize=(12, 8))

ax = fig.add_subplot(1,1,1, projection='3d')

ax.plot_surface(X, Y, Z, rstride=4, cstride=4, alpha=0.25)
cset = ax.contour(X, Y, Z, zdir='z', offset=-pi, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='x', offset=-pi, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=3*pi, cmap=cm.coolwarm)

ax.set_xlim3d(-pi, 2*pi);
ax.set_ylim3d(0, 3*pi);
ax.set_zlim3d(-pi, 2*pi);

# %% [markdown]
# ## Decorators

# %% [markdown]
# A callable that takes another function as an argument.

# %%
def add_one(x):
    """Simple function"""
    return x + 1

def add_two_more(function):
    """A decorator"""
    def inner(z):
        return function(z) + 2
    return inner

add_three = add_two_more(add_one)
add_three(0)
# Out:
# 3

# %% [markdown]
# #### Alternate syntax

# %%
@add_two_more
def to_few(n):
    """Just too few"""
    return n

print to_few(3)
# Out:
# 5

# %%
print to_few.__name__
# Out:
# inner

# %%
print to_few.__doc__
# Out:
# None

# %% [markdown]
# https://docs.python.org/2/library/functools.html#functools.wraps

# %%
from functools import wraps

def add_two_more(function):
    """A decorator"""
    @wraps(function)
    def wrapped_func(z):
        return function(z) + 2
    return wrapped_func

# %%
@add_two_more
def to_few(n):
    """Just too few"""
    return n
print to_few.__name__
print to_few.__doc__
# Out:
# to_few
# Just too few

# %% [markdown]
# ## ``*args`` & ``**kwargs``

# %%
def print_args(*args):
    print args
    for arg in args:
        print arg

print_args(1, 'plog', '***...***')
# Out:
# (1, 'plog', '***...***')
# 1
# plog
# ***...***

# %%
def print_kwargs(**kwargs):
    print kwargs
    for key, value in kwargs.items():
        print key, '=', value
print_kwargs(genre='jazz', tempo='fast', action='dance')
# Out:
# {'genre': 'jazz', 'action': 'dance', 'tempo': 'fast'}
# genre = jazz
# action = dance
# tempo = fast

# %%
def get_album(upc, artist=None, title=None, *args, **kwargs):
    # ...
    # I can use any extra args and kwargs, if given, to 
    # effect the result of this function.
    pass

# %% [markdown]
# ## Generators
# https://www.jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/

# %%
def integers(start=0):
    while start < 3:
        yield start
        start += 1

# %%
ints = integers()
ints
# Out:
# <generator object integers at 0x11c036cd0>

# %%
ints.next()
# Out:
# 0

# %%
ints.next()
# Out:
# 1

# %%
ints.next()
# Out:
# 2

# %%
ints.next()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-218-c5ac41f3b3a9> in <module>()
# ----> 1 ints.next()
#
# StopIteration:

# %%
for j in integers(-2):
    print j
# Out:
# -2
# -1
# 0
# 1
# 2

# %%
def pi_digits():
    numerator, denominator = 22.0, 7.0
    while True:
        quotient, remainder = divmod(numerator, denominator)
        yield int(quotient)
        numerator = remainder * 10

# %%
digits = pi_digits()
[digits.next() for _ in xrange(10)]
# Out:
# [3, 1, 4, 2, 8, 5, 7, 1, 4, 2]

# %%
22 / 7.0
# Out:
# 3.142857142857143

# %%
21.99119 / 7.0
# Out:
# 3.1415985714285712

# %% [markdown]
# ## Extra Fun

# %% [markdown]
#     $ pip install pyladies

# %% [markdown]
# ## Bibilography

# %% [markdown]
# - http://nbviewer.ipython.org/github/jrjohansson/scientific-python-lectures/blob/master/Lecture-4-Matplotlib.ipynb
# - http://blog.dscpl.com.au/search/label/decorators
